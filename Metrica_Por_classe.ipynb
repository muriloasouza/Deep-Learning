# %% [markdown]
# <a href="https://colab.research.google.com/github/muriloasouza/Deep-Learning/blob/master/Metrica_Por_classe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install tensorflow 2.x in Colab

try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
    pass
  
# Import libraries  
from __future__ import absolute_import, division, print_function, unicode_literals

#Power data classification/regression with CNN
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import time as time
import matplotlib.pyplot as plt
import pydot
import csv as csv
import keras.backend as K
import itertools
# %matplotlib inline
print("TensorFlow version:",tf.__version__)
# Out:
# TensorFlow 2.x selected.
# TensorFlow version: 2.0.0
# Using TensorFlow backend.

# %%
# Downloading data files 
# !wget https://raw.githubusercontent.com/muriloasouza/Deep-Learning/master/Input.txt
# !wget https://raw.githubusercontent.com/muriloasouza/Deep-Learning/master/Labels.txt
# !wget https://raw.githubusercontent.com/muriloasouza/Deep-Learning/master/Input_Train.txt
# !wget https://raw.githubusercontent.com/muriloasouza/Deep-Learning/master/Labels_Train.txt
# !wget https://raw.githubusercontent.com/muriloasouza/Deep-Learning/master/Input_Valid.txt
# !wget https://raw.githubusercontent.com/muriloasouza/Deep-Learning/master/Labels_Valid.txt
  
def data_set_size(csv_file):
    with open(csv_file) as csvfile:
        csv_rows = 0
        for _ in csvfile:
            csv_rows += 1
    return csv_rows-1            #Remove header from count and return

labels = "./Labels.txt"
labels_train = "./Labels_Train.txt"
labels_valid = "./Labels_Valid.txt"
total = data_set_size(labels)
total_train = data_set_size(labels_train)
total_valid = data_set_size(labels_valid)
print("Total Samples:",total)
print("Total Training Samples:",total_train)
print("Total Validation Samples:",total_valid)
# Out:
# --2019-12-14 16:01:39--  https://raw.githubusercontent.com/muriloasouza/Deep-Learning/master/Input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 892480 (872K) [text/plain]
# Saving to: ‘Input.txt’
#
# Input.txt           100%[===================>] 871.56K  --.-KB/s    in 0.06s
#
# 2019-12-14 16:01:39 (13.1 MB/s) - ‘Input.txt’ saved [892480/892480]
#
# --2019-12-14 16:01:42--  https://raw.githubusercontent.com/muriloasouza/Deep-Learning/master/Labels.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 86669 (85K) [text/plain]
# Saving to: ‘Labels.txt’
#
# Labels.txt          100%[===================>]  84.64K  --.-KB/s    in 0.02s
#
# 2019-12-14 16:01:42 (3.37 MB/s) - ‘Labels.txt’ saved [86669/86669]
#
# --2019-12-14 16:01:46--  https://raw.githubusercontent.com/muriloasouza/Deep-Learning/master/Input_Train.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 581395 (568K) [text/plain]
# Saving to: ‘Input_Train.txt’
#
# Input_Train.txt     100%[===================>] 567.77K  --.-KB/s    in 0.06s
#
# 2019-12-14 16:01:46 (8.60 MB/s) - ‘Input_Train.txt’ saved [581395/581395]
#
# --2019-12-14 16:01:49--  https://raw.githubusercontent.com/muriloasouza/Deep-Learning/master/Labels_Train.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54987 (54K) [text/plain]
# Saving to: ‘Labels_Train.txt’
#
# Labels_Train.txt    100%[===================>]  53.70K  --.-KB/s    in 0.03s
#
# 2019-12-14 16:01:49 (2.08 MB/s) - ‘Labels_Train.txt’ saved [54987/54987]
#
# --2019-12-14 16:01:51--  https://raw.githubusercontent.com/muriloasouza/Deep-Learning/master/Input_Valid.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 145934 (143K) [text/plain]
# Saving to: ‘Input_Valid.txt’
#
# Input_Valid.txt     100%[===================>] 142.51K  --.-KB/s    in 0.04s
#
# 2019-12-14 16:01:51 (3.77 MB/s) - ‘Input_Valid.txt’ saved [145934/145934]
#
# --2019-12-14 16:01:54--  https://raw.githubusercontent.com/muriloasouza/Deep-Learning/master/Labels_Valid.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14018 (14K) [text/plain]
# Saving to: ‘Labels_Valid.txt’
#
# Labels_Valid.txt    100%[===================>]  13.69K  --.-KB/s    in 0.01s
#
# 2019-12-14 16:01:54 (1.11 MB/s) - ‘Labels_Valid.txt’ saved [14018/14018]
#
# Total Samples: 1147
# Total Training Samples: 918
# Total Validation Samples: 229

# %%
#Python generator to supply batches of traning data during training with loading full data set to memory
def power_data_generator(batch_size,gen_type=''):
    while 1:
        df_input_train=pd.read_csv('./Input_Train.txt',usecols =['Wind_MWh','Actual_Load_MWh'],chunksize = 24*batch_size, iterator=True)
        df_target_train=pd.read_csv('./Labels_Train.txt',usecols =['Potencia_Media_do_Vento_(MW)','Desvio_Padrao_Vento_(MW)','FCSPV_(Fracao_de_Carga_Suprida_pela_Potencia_do_Vento)'],chunksize = batch_size, iterator=True)
        df_input_valid=pd.read_csv('./Input_Valid.txt',usecols =['Wind_MWh','Actual_Load_MWh'],chunksize = 24*batch_size, iterator=True)
        df_target_valid=pd.read_csv('./Labels_Valid.txt',usecols =['Potencia_Media_do_Vento_(MW)','Desvio_Padrao_Vento_(MW)','FCSPV_(Fracao_de_Carga_Suprida_pela_Potencia_do_Vento)'],chunksize = batch_size, iterator=True)
        for chunk, chunk2, chunk3, chunk4 in zip(df_input_train,df_target_train,df_input_valid,df_target_valid):
          X_train = chunk.values
          X_train = np.resize(X_train,(batch_size,24,2,1))
          Y_train = chunk2.values
          X_valid = chunk3.values
          X_valid = np.resize(X_valid,(batch_size,24,2,1))
          Y_valid = chunk4.values
          if len(Y_train) < batch_size:
            X_train = X_train[:-batch_size*len(Y_valid)]
            Y_train = Y_train[:-len(Y_valid)]
          if len(Y_valid) < batch_size:
            X_valid = X_valid[:-batch_size*len(Y_valid)]
            Y_valid = Y_valid[:-len(Y_valid)]       
          if gen_type =='training':
            yield (X_train[0:batch_size],Y_train[0:batch_size])
          elif gen_type =='validation':
            yield (X_valid[0:batch_size],Y_valid[0:batch_size])
          elif gen_type =='inference':
            yield X_valid

# %%
# Custom Metric

def nossa_metrica(y_true, y_pred): # Overall metric
  truepotventolow = K.cast(K.less_equal(y_true[:,0], 4000), 'int8')
  predpotventolow = K.cast(K.less_equal(y_pred[:,0], 4000), 'int8')
  potventolow = K.sum(truepotventolow*predpotventolow)
  truepotventomed = K.cast(K.greater(y_true[:,0], 4000) & K.less_equal(y_true[:,0], 8500), 'int8')
  predpotventomed = K.cast(K.greater(y_pred[:,0], 4000) & K.less_equal(y_pred[:,0], 8500), 'int8')
  potventomed = K.sum(truepotventomed*predpotventomed)
  truepotventohigh = K.cast(K.greater(y_true[:,0], 8500), 'int8')
  predpotventohigh = K.cast(K.greater(y_pred[:,0], 8500), 'int8')
  potventohigh = K.sum(truepotventohigh*predpotventohigh)
  truedesvpadlow = K.cast(K.less_equal(y_true[:,1], 1150), 'int8')
  preddesvpadlow = K.cast(K.less_equal(y_pred[:,1], 1150), 'int8')
  desvpadlow = K.sum(truedesvpadlow*preddesvpadlow)
  truedesvpadmed = K.cast(K.greater(y_true[:,1], 1150) & K.less_equal(y_true[:,1], 2300), 'int8')
  preddesvpadmed = K.cast(K.greater(y_pred[:,1], 1150) & K.less_equal(y_pred[:,1], 2300), 'int8')
  desvpadmed = K.sum(truedesvpadmed*preddesvpadmed)
  truedesvpadhigh = K.cast(K.greater(y_true[:,1], 2300), 'int8')
  preddesvpadhigh = K.cast(K.greater(y_pred[:,1], 2300), 'int8')
  desvpadhigh = K.sum(truedesvpadhigh*preddesvpadhigh)
  truewlslow = K.cast(K.less_equal(y_true[:,2], 0.075), 'int8')
  predwlslow = K.cast(K.less_equal(y_pred[:,2], 0.075), 'int8')
  wlslow = K.sum(truewlslow*predwlslow)   
  truewlshigh = K.cast(K.greater(y_true[:,2], 0.075), 'int8')
  predwlshigh = K.cast(K.greater(y_pred[:,2], 0.075), 'int8')
  wlshigh = K.sum(truewlshigh*predwlshigh)
  return (potventolow+potventomed+potventohigh+desvpadlow+desvpadmed+desvpadhigh+wlslow+wlshigh)/(Yclasses*batch_size)

def potvento(y_true, y_pred): # Metric for first class
  truepotventolow = K.cast(K.less_equal(y_true[:,0], 4000), 'int8')
  predpotventolow = K.cast(K.less_equal(y_pred[:,0], 4000), 'int8')
  potventolow = K.sum(truepotventolow*predpotventolow)
  truepotventomed = K.cast(K.greater(y_true[:,0], 4000) & K.less_equal(y_true[:,0], 8500), 'int8')
  predpotventomed = K.cast(K.greater(y_pred[:,0], 4000) & K.less_equal(y_pred[:,0], 8500), 'int8')
  potventomed = K.sum(truepotventomed*predpotventomed)
  truepotventohigh = K.cast(K.greater(y_true[:,0], 8500), 'int8')
  predpotventohigh = K.cast(K.greater(y_pred[:,0], 8500), 'int8')
  potventohigh = K.sum(truepotventohigh*predpotventohigh)
  return (potventolow+potventomed+potventohigh)/(batch_size)

def desvpad(y_true, y_pred): # Metric for second class
  truedesvpadlow = K.cast(K.less_equal(y_true[:,1], 1150), 'int8')
  preddesvpadlow = K.cast(K.less_equal(y_pred[:,1], 1150), 'int8')
  desvpadlow = K.sum(truedesvpadlow*preddesvpadlow)
  truedesvpadmed = K.cast(K.greater(y_true[:,1], 1150) & K.less_equal(y_true[:,1], 2300), 'int8')
  preddesvpadmed = K.cast(K.greater(y_pred[:,1], 1150) & K.less_equal(y_pred[:,1], 2300), 'int8')
  desvpadmed = K.sum(truedesvpadmed*preddesvpadmed)
  truedesvpadhigh = K.cast(K.greater(y_true[:,1], 2300), 'int8')
  preddesvpadhigh = K.cast(K.greater(y_pred[:,1], 2300), 'int8')
  desvpadhigh = K.sum(truedesvpadhigh*preddesvpadhigh)    
  return (desvpadlow+desvpadmed+desvpadhigh)/(batch_size)

def wls(y_true, y_pred): # Metric for third class
  truewlslow = K.cast(K.less_equal(y_true[:,2], 0.075), 'int8')
  predwlslow = K.cast(K.less_equal(y_pred[:,2], 0.075), 'int8')
  wlslow = K.sum(truewlslow*predwlslow)   
  truewlshigh = K.cast(K.greater(y_true[:,2], 0.075), 'int8')
  predwlshigh = K.cast(K.greater(y_pred[:,2], 0.075), 'int8')
  wlshigh = K.sum(truewlshigh*predwlshigh)  
  return (wlslow+wlshigh)/(batch_size)

# %%
#Define model using Keras

batch_size = 16
Yclasses = 3 # Number of output classes
bias0 =  'zeros'
kernel0 = 'glorot_uniform'
#dropout = 0.1


model = keras.Sequential([
    tf.keras.layers.Input(shape=(24,2,1),name='InputLayer'),                    
    tf.keras.layers.Conv2D(filters=4,kernel_size=(6,2),strides=(1,1),activation='relu',bias_initializer=bias0,kernel_initializer=kernel0,name='ConvLayer1'),
    #tf.keras.layers.Dropout(rate=dropout),
    tf.keras.layers.Conv2D(filters=4,kernel_size=(6,1),strides=(1,1),activation='relu',bias_initializer=bias0,kernel_initializer=kernel0,name='ConvLayer2'),
    #tf.keras.layers.Dropout(rate=dropout),
    tf.keras.layers.Flatten(name="Flatten"),
    tf.keras.layers.Dense(units = 8,activation='relu',bias_initializer=bias0,kernel_initializer=kernel0,name='FeedForward1'),
    #tf.keras.layers.Dropout(rate=dropout),
    tf.keras.layers.Dense(units = 8,activation='relu',bias_initializer=bias0,kernel_initializer=kernel0,name='FeedForward2'),
    #tf.keras.layers.Dropout(rate=dropout),
    tf.keras.layers.Dense(units = 8,activation='relu',bias_initializer=bias0,kernel_initializer=kernel0,name='FeedForward3'),
    #tf.keras.layers.Dropout(rate=dropout),
    tf.keras.layers.Dense(units = 8,activation='relu',bias_initializer=bias0,kernel_initializer=kernel0,name='FeedForward4'),
    #tf.keras.layers.Dropout(rate=dropout),
    tf.keras.layers.Dense(units = Yclasses,bias_initializer=bias0,kernel_initializer=kernel0,name='OutputLayer'),
])
model.compile(loss='mse',optimizer='adam',verbose = 2,metrics=[nossa_metrica,potvento,desvpad,wls])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# ConvLayer1 (Conv2D)          (None, 19, 1, 4)          52
# _________________________________________________________________
# ConvLayer2 (Conv2D)          (None, 14, 1, 4)          100
# _________________________________________________________________
# Flatten (Flatten)            (None, 56)                0
# _________________________________________________________________
# FeedForward1 (Dense)         (None, 8)                 456
# _________________________________________________________________
# FeedForward2 (Dense)         (None, 8)                 72
# _________________________________________________________________
# FeedForward3 (Dense)         (None, 8)                 72
# _________________________________________________________________
# FeedForward4 (Dense)         (None, 8)                 72
# _________________________________________________________________
# OutputLayer (Dense)          (None, 3)                 27
# =================================================================
# Total params: 851
# Trainable params: 851
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_generator= power_data_generator(batch_size=batch_size,gen_type='training')
valid_generator= power_data_generator(batch_size=batch_size,gen_type='validation')
number_of_training_batches = np.int32(total_train/batch_size)
number_of_validation_batches = np.int32(total_valid/batch_size) 
#Training starts
t = time.time()
history = model.fit_generator(train_generator, steps_per_epoch= number_of_training_batches,epochs=2000,validation_data=valid_generator, validation_steps=number_of_validation_batches,verbose=2)
print("Loss de treinamento minima:",min(history.history["loss"]))
print("Acuracia de treinamento maxima:",max(history.history["nossa_metrica"]))
print("Loss de valdiacao minima:",min(history.history["val_loss"]))
print("Acuracia de validacao maxima:",max(history.history["val_nossa_metrica"])) 
print("Time: %.3f minutes" % ((time.time() - t)/60))
model.save('model.h5')
print("Model Saved")
# Out:
# Epoch 1/2000
# 57/57 - 8s - loss: 7359474.8092 - nossa_metrica: 0.5395 - potvento: 0.5296 - desvpad: 0.5877 - wls: 0.5011 - val_loss: 12554256.4732 - val_nossa_metrica: 0.4137 - val_potvento: 0.3214 - val_desvpad: 0.4241 - val_wls: 0.4955
# Epoch 2/2000
# 57/57 - 5s - loss: 3261031.9764 - nossa_metrica: 0.4810 - potvento: 0.5274 - desvpad: 0.4200 - wls: 0.4956 - val_loss: 3747212.7946 - val_nossa_metrica: 0.3750 - val_potvento: 0.3884 - val_desvpad: 0.2455 - val_wls: 0.4911
# Epoch 3/2000
# 57/57 - 5s - loss: 1616389.3871 - nossa_metrica: 0.4773 - potvento: 0.5208 - desvpad: 0.4221 - wls: 0.4890 - val_loss: 3257889.9777 - val_nossa_metrica: 0.4360 - val_potvento: 0.4196 - val_desvpad: 0.4196 - val_wls: 0.4688
# Epoch 4/2000
# 57/57 - 5s - loss: 1389305.9704 - nossa_metrica: 0.5563 - potvento: 0.5822 - desvpad: 0.5746 - wls: 0.5121 - val_loss: 2995127.3750 - val_nossa_metrica: 0.5461 - val_potvento: 0.4777 - val_desvpad: 0.4688 - val_wls: 0.6920
# Epoch 5/2000
# 57/57 - 5s - loss: 1233555.3492 - nossa_metrica: 0.6115 - potvento: 0.6469 - desvpad: 0.6086 - wls: 0.5789 - val_loss: 2219636.1250 - val_nossa_metrica: 0.5268 - val_potvento: 0.4509 - val_desvpad: 0.4777 - val_wls: 0.6518
# Epoch 6/2000
# 57/57 - 5s - loss: 1023507.7851 - nossa_metrica: 0.6597 - potvento: 0.7193 - desvpad: 0.5932 - wls: 0.6667 - val_loss: 1926761.6652 - val_nossa_metrica: 0.4955 - val_potvento: 0.4196 - val_desvpad: 0.4241 - val_wls: 0.6429
# Epoch 7/2000
# 57/57 - 5s - loss: 816672.5252 - nossa_metrica: 0.7039 - potvento: 0.8147 - desvpad: 0.5866 - wls: 0.7105 - val_loss: 1404191.6607 - val_nossa_metrica: 0.5967 - val_potvento: 0.5312 - val_desvpad: 0.5312 - val_wls: 0.7277
# Epoch 8/2000
# 57/57 - 5s - loss: 505822.9370 - nossa_metrica: 0.7372 - potvento: 0.8904 - desvpad: 0.5800 - wls: 0.7412 - val_loss: 615577.4230 - val_nossa_metrica: 0.6012 - val_potvento: 0.7098 - val_desvpad: 0.5223 - val_wls: 0.5714
# Epoch 9/2000
# 57/57 - 5s - loss: 213201.2197 - nossa_metrica: 0.6001 - potvento: 0.9452 - desvpad: 0.5713 - wls: 0.2840 - val_loss: 327117.0884 - val_nossa_metrica: 0.4911 - val_potvento: 0.8304 - val_desvpad: 0.5357 - val_wls: 0.1071
# Epoch 10/2000
# 57/57 - 5s - loss: 136717.2024 - nossa_metrica: 0.5457 - potvento: 0.9682 - desvpad: 0.5658 - wls: 0.1031 - val_loss: 289586.2606 - val_nossa_metrica: 0.5298 - val_potvento: 0.9241 - val_desvpad: 0.5714 - val_wls: 0.0938
# Epoch 11/2000
# 57/57 - 5s - loss: 127746.4768 - nossa_metrica: 0.5373 - potvento: 0.9704 - desvpad: 0.5515 - wls: 0.0899 - val_loss: 236714.6529 - val_nossa_metrica: 0.4881 - val_potvento: 0.8571 - val_desvpad: 0.5312 - val_wls: 0.0759
# Epoch 12/2000
# 57/57 - 5s - loss: 121343.9830 - nossa_metrica: 0.5512 - potvento: 0.9726 - desvpad: 0.5702 - wls: 0.1107 - val_loss: 244898.0340 - val_nossa_metrica: 0.5030 - val_potvento: 0.8616 - val_desvpad: 0.5179 - val_wls: 0.1295
# Epoch 13/2000
# 57/57 - 5s - loss: 116318.1759 - nossa_metrica: 0.5563 - potvento: 0.9704 - desvpad: 0.5779 - wls: 0.1206 - val_loss: 254366.4057 - val_nossa_metrica: 0.5372 - val_potvento: 0.9241 - val_desvpad: 0.5491 - val_wls: 0.1384
# Epoch 14/2000
# 57/57 - 5s - loss: 112590.9079 - nossa_metrica: 0.5585 - potvento: 0.9693 - desvpad: 0.5822 - wls: 0.1239 - val_loss: 221286.7012 - val_nossa_metrica: 0.5000 - val_potvento: 0.8661 - val_desvpad: 0.5268 - val_wls: 0.1071
# Epoch 15/2000
# 57/57 - 5s - loss: 106893.4248 - nossa_metrica: 0.5559 - potvento: 0.9715 - desvpad: 0.5844 - wls: 0.1118 - val_loss: 234670.6275 - val_nossa_metrica: 0.4970 - val_potvento: 0.8661 - val_desvpad: 0.5268 - val_wls: 0.0982
# Epoch 16/2000
# 57/57 - 5s - loss: 108633.6779 - nossa_metrica: 0.5530 - potvento: 0.9737 - desvpad: 0.5702 - wls: 0.1151 - val_loss: 236224.0195 - val_nossa_metrica: 0.5402 - val_potvento: 0.9241 - val_desvpad: 0.5670 - val_wls: 0.1295
# Epoch 17/2000
# 57/57 - 5s - loss: 103625.8969 - nossa_metrica: 0.5545 - potvento: 0.9792 - desvpad: 0.5779 - wls: 0.1064 - val_loss: 204805.2879 - val_nossa_metrica: 0.4970 - val_potvento: 0.8571 - val_desvpad: 0.5179 - val_wls: 0.1161
# Epoch 18/2000
# 57/57 - 5s - loss: 99403.7331 - nossa_metrica: 0.5574 - potvento: 0.9792 - desvpad: 0.5877 - wls: 0.1053 - val_loss: 212331.9420 - val_nossa_metrica: 0.5074 - val_potvento: 0.8705 - val_desvpad: 0.5223 - val_wls: 0.1295
# Epoch 19/2000
# 57/57 - 5s - loss: 95492.1586 - nossa_metrica: 0.5629 - potvento: 0.9781 - desvpad: 0.5998 - wls: 0.1107 - val_loss: 225012.6696 - val_nossa_metrica: 0.5313 - val_potvento: 0.9241 - val_desvpad: 0.5536 - val_wls: 0.1161
# Epoch 20/2000
# 57/57 - 5s - loss: 89643.1280 - nossa_metrica: 0.5683 - potvento: 0.9792 - desvpad: 0.6107 - wls: 0.1151 - val_loss: 194238.4247 - val_nossa_metrica: 0.4985 - val_potvento: 0.8661 - val_desvpad: 0.5223 - val_wls: 0.1071
# Epoch 21/2000
# 57/57 - 5s - loss: 90574.5289 - nossa_metrica: 0.5640 - potvento: 0.9781 - desvpad: 0.5932 - wls: 0.1206 - val_loss: 195349.9219 - val_nossa_metrica: 0.5030 - val_potvento: 0.8705 - val_desvpad: 0.5089 - val_wls: 0.1295
# Epoch 22/2000
# 57/57 - 5s - loss: 86080.3504 - nossa_metrica: 0.5658 - potvento: 0.9814 - desvpad: 0.5943 - wls: 0.1217 - val_loss: 201981.1334 - val_nossa_metrica: 0.5387 - val_potvento: 0.9241 - val_desvpad: 0.5357 - val_wls: 0.1562
# Epoch 23/2000
# 57/57 - 5s - loss: 82580.1462 - nossa_metrica: 0.5702 - potvento: 0.9792 - desvpad: 0.5965 - wls: 0.1349 - val_loss: 176776.6730 - val_nossa_metrica: 0.5060 - val_potvento: 0.8661 - val_desvpad: 0.5223 - val_wls: 0.1295
# Epoch 24/2000
# 57/57 - 5s - loss: 79934.2085 - nossa_metrica: 0.5768 - potvento: 0.9781 - desvpad: 0.6129 - wls: 0.1393 - val_loss: 182406.0901 - val_nossa_metrica: 0.4970 - val_potvento: 0.8661 - val_desvpad: 0.5134 - val_wls: 0.1116
# Epoch 25/2000
# 57/57 - 5s - loss: 75876.8748 - nossa_metrica: 0.5775 - potvento: 0.9792 - desvpad: 0.6151 - wls: 0.1382 - val_loss: 191650.9277 - val_nossa_metrica: 0.5164 - val_potvento: 0.9286 - val_desvpad: 0.5268 - val_wls: 0.0938
# Epoch 26/2000
# 57/57 - 5s - loss: 78231.6885 - nossa_metrica: 0.5694 - potvento: 0.9781 - desvpad: 0.5888 - wls: 0.1414 - val_loss: 165148.6942 - val_nossa_metrica: 0.4985 - val_potvento: 0.8616 - val_desvpad: 0.5089 - val_wls: 0.1250
# Epoch 27/2000
# 57/57 - 5s - loss: 74760.1300 - nossa_metrica: 0.5789 - potvento: 0.9814 - desvpad: 0.6184 - wls: 0.1371 - val_loss: 171948.4771 - val_nossa_metrica: 0.5208 - val_potvento: 0.8661 - val_desvpad: 0.5312 - val_wls: 0.1652
# Epoch 28/2000
# 57/57 - 5s - loss: 72687.9471 - nossa_metrica: 0.5789 - potvento: 0.9792 - desvpad: 0.6195 - wls: 0.1382 - val_loss: 184604.5525 - val_nossa_metrica: 0.5551 - val_potvento: 0.9330 - val_desvpad: 0.5670 - val_wls: 0.1652
# Epoch 29/2000
# 57/57 - 5s - loss: 71381.6578 - nossa_metrica: 0.5768 - potvento: 0.9781 - desvpad: 0.6151 - wls: 0.1371 - val_loss: 158785.7266 - val_nossa_metrica: 0.4970 - val_potvento: 0.8616 - val_desvpad: 0.5223 - val_wls: 0.1071
# Epoch 30/2000
# 57/57 - 5s - loss: 68891.9662 - nossa_metrica: 0.5764 - potvento: 0.9770 - desvpad: 0.6096 - wls: 0.1425 - val_loss: 168196.2556 - val_nossa_metrica: 0.4896 - val_potvento: 0.8795 - val_desvpad: 0.5089 - val_wls: 0.0804
# Epoch 31/2000
# 57/57 - 5s - loss: 72527.2580 - nossa_metrica: 0.5727 - potvento: 0.9748 - desvpad: 0.5943 - wls: 0.1491 - val_loss: 171408.2123 - val_nossa_metrica: 0.5461 - val_potvento: 0.9509 - val_desvpad: 0.5491 - val_wls: 0.1384
# Epoch 32/2000
# 57/57 - 5s - loss: 70763.1384 - nossa_metrica: 0.5782 - potvento: 0.9770 - desvpad: 0.6173 - wls: 0.1404 - val_loss: 156307.2924 - val_nossa_metrica: 0.5342 - val_potvento: 0.8705 - val_desvpad: 0.5357 - val_wls: 0.1964
# Epoch 33/2000
# 57/57 - 5s - loss: 70503.3301 - nossa_metrica: 0.5786 - potvento: 0.9748 - desvpad: 0.6250 - wls: 0.1360 - val_loss: 182377.9515 - val_nossa_metrica: 0.5372 - val_potvento: 0.8705 - val_desvpad: 0.5402 - val_wls: 0.2009
# Epoch 34/2000
# 57/57 - 5s - loss: 70132.5676 - nossa_metrica: 0.5793 - potvento: 0.9737 - desvpad: 0.6294 - wls: 0.1349 - val_loss: 167783.6083 - val_nossa_metrica: 0.5432 - val_potvento: 0.9330 - val_desvpad: 0.5714 - val_wls: 0.1250
# Epoch 35/2000
# 57/57 - 5s - loss: 67984.5512 - nossa_metrica: 0.5815 - potvento: 0.9748 - desvpad: 0.6327 - wls: 0.1371 - val_loss: 164605.3195 - val_nossa_metrica: 0.4717 - val_potvento: 0.8705 - val_desvpad: 0.4777 - val_wls: 0.0670
# Epoch 36/2000
# 57/57 - 5s - loss: 72461.2280 - nossa_metrica: 0.5768 - potvento: 0.9726 - desvpad: 0.6184 - wls: 0.1393 - val_loss: 154480.5949 - val_nossa_metrica: 0.5015 - val_potvento: 0.8705 - val_desvpad: 0.5089 - val_wls: 0.1250
# Epoch 37/2000
# 57/57 - 5s - loss: 71853.8901 - nossa_metrica: 0.5808 - potvento: 0.9649 - desvpad: 0.6447 - wls: 0.1327 - val_loss: 179904.8376 - val_nossa_metrica: 0.5789 - val_potvento: 0.9330 - val_desvpad: 0.5804 - val_wls: 0.2232
# Epoch 38/2000
# 57/57 - 5s - loss: 72328.0145 - nossa_metrica: 0.5775 - potvento: 0.9583 - desvpad: 0.6414 - wls: 0.1327 - val_loss: 198673.7478 - val_nossa_metrica: 0.5342 - val_potvento: 0.8527 - val_desvpad: 0.5491 - val_wls: 0.2009
# Epoch 39/2000
# 57/57 - 5s - loss: 74351.6980 - nossa_metrica: 0.5841 - potvento: 0.9561 - desvpad: 0.6524 - wls: 0.1436 - val_loss: 147151.3041 - val_nossa_metrica: 0.5149 - val_potvento: 0.8884 - val_desvpad: 0.5312 - val_wls: 0.1250
# Epoch 40/2000
# 57/57 - 5s - loss: 73746.8949 - nossa_metrica: 0.5914 - potvento: 0.9539 - desvpad: 0.6656 - wls: 0.1546 - val_loss: 202550.4096 - val_nossa_metrica: 0.5119 - val_potvento: 0.9062 - val_desvpad: 0.5402 - val_wls: 0.0893
# Epoch 41/2000
# 57/57 - 5s - loss: 79033.0243 - nossa_metrica: 0.5819 - potvento: 0.9485 - desvpad: 0.6458 - wls: 0.1513 - val_loss: 139086.4534 - val_nossa_metrica: 0.5149 - val_potvento: 0.8795 - val_desvpad: 0.5223 - val_wls: 0.1429
# Epoch 42/2000
# 57/57 - 5s - loss: 74999.1409 - nossa_metrica: 0.5885 - potvento: 0.9452 - desvpad: 0.6678 - wls: 0.1524 - val_loss: 189270.0943 - val_nossa_metrica: 0.5476 - val_potvento: 0.8616 - val_desvpad: 0.5402 - val_wls: 0.2411
# Epoch 43/2000
# 57/57 - 5s - loss: 71781.0648 - nossa_metrica: 0.5910 - potvento: 0.9529 - desvpad: 0.6678 - wls: 0.1524 - val_loss: 189962.7227 - val_nossa_metrica: 0.5848 - val_potvento: 0.9330 - val_desvpad: 0.5759 - val_wls: 0.2455
# Epoch 44/2000
# 57/57 - 5s - loss: 68646.6868 - nossa_metrica: 0.6020 - potvento: 0.9583 - desvpad: 0.6842 - wls: 0.1634 - val_loss: 133660.1443 - val_nossa_metrica: 0.5045 - val_potvento: 0.8750 - val_desvpad: 0.5134 - val_wls: 0.1250
# Epoch 45/2000
# 57/57 - 5s - loss: 62804.6807 - nossa_metrica: 0.6086 - potvento: 0.9770 - desvpad: 0.6897 - wls: 0.1590 - val_loss: 147711.4922 - val_nossa_metrica: 0.4911 - val_potvento: 0.8705 - val_desvpad: 0.4955 - val_wls: 0.1071
# Epoch 46/2000
# 57/57 - 5s - loss: 64437.3380 - nossa_metrica: 0.6140 - potvento: 0.9781 - desvpad: 0.6963 - wls: 0.1678 - val_loss: 138362.6987 - val_nossa_metrica: 0.5804 - val_potvento: 0.9464 - val_desvpad: 0.5804 - val_wls: 0.2143
# Epoch 47/2000
# 57/57 - 5s - loss: 59880.4489 - nossa_metrica: 0.6228 - potvento: 0.9792 - desvpad: 0.7160 - wls: 0.1732 - val_loss: 141783.6300 - val_nossa_metrica: 0.5580 - val_potvento: 0.8705 - val_desvpad: 0.5536 - val_wls: 0.2500
# Epoch 48/2000
# 57/57 - 5s - loss: 57601.4532 - nossa_metrica: 0.6360 - potvento: 0.9792 - desvpad: 0.7325 - wls: 0.1963 - val_loss: 140911.5145 - val_nossa_metrica: 0.5818 - val_potvento: 0.8795 - val_desvpad: 0.5625 - val_wls: 0.3036
# Epoch 49/2000
# 57/57 - 5s - loss: 56862.6166 - nossa_metrica: 0.6612 - potvento: 0.9814 - desvpad: 0.7368 - wls: 0.2654 - val_loss: 125573.7877 - val_nossa_metrica: 0.5804 - val_potvento: 0.9420 - val_desvpad: 0.5714 - val_wls: 0.2277
# Epoch 50/2000
# 57/57 - 5s - loss: 56186.1724 - nossa_metrica: 0.6897 - potvento: 0.9825 - desvpad: 0.7346 - wls: 0.3520 - val_loss: 145497.6722 - val_nossa_metrica: 0.5104 - val_potvento: 0.8705 - val_desvpad: 0.4821 - val_wls: 0.1786
# Epoch 51/2000
# 57/57 - 5s - loss: 59845.0232 - nossa_metrica: 0.7054 - potvento: 0.9781 - desvpad: 0.7226 - wls: 0.4156 - val_loss: 112075.8005 - val_nossa_metrica: 0.5774 - val_potvento: 0.8884 - val_desvpad: 0.5223 - val_wls: 0.3214
# Epoch 52/2000
# 57/57 - 5s - loss: 55230.5013 - nossa_metrica: 0.7405 - potvento: 0.9792 - desvpad: 0.7675 - wls: 0.4748 - val_loss: 152874.8934 - val_nossa_metrica: 0.7143 - val_potvento: 0.9330 - val_desvpad: 0.6161 - val_wls: 0.5938
# Epoch 53/2000
# 57/57 - 5s - loss: 52742.1094 - nossa_metrica: 0.7558 - potvento: 0.9792 - desvpad: 0.7818 - wls: 0.5066 - val_loss: 125380.7037 - val_nossa_metrica: 0.6860 - val_potvento: 0.8795 - val_desvpad: 0.5893 - val_wls: 0.5893
# Epoch 54/2000
# 57/57 - 5s - loss: 50878.2893 - nossa_metrica: 0.7686 - potvento: 0.9781 - desvpad: 0.7829 - wls: 0.5450 - val_loss: 100093.1727 - val_nossa_metrica: 0.6726 - val_potvento: 0.8839 - val_desvpad: 0.5536 - val_wls: 0.5804
# Epoch 55/2000
# 57/57 - 5s - loss: 48736.7896 - nossa_metrica: 0.7964 - potvento: 0.9814 - desvpad: 0.7884 - wls: 0.6195 - val_loss: 122315.7718 - val_nossa_metrica: 0.7039 - val_potvento: 0.9464 - val_desvpad: 0.5938 - val_wls: 0.5714
# Epoch 56/2000
# 57/57 - 5s - loss: 49612.3416 - nossa_metrica: 0.7982 - potvento: 0.9770 - desvpad: 0.7818 - wls: 0.6360 - val_loss: 95152.0974 - val_nossa_metrica: 0.6935 - val_potvento: 0.8839 - val_desvpad: 0.5804 - val_wls: 0.6161
# Epoch 57/2000
# 57/57 - 5s - loss: 46850.0787 - nossa_metrica: 0.8077 - potvento: 0.9748 - desvpad: 0.7928 - wls: 0.6557 - val_loss: 126785.1624 - val_nossa_metrica: 0.7173 - val_potvento: 0.8795 - val_desvpad: 0.5938 - val_wls: 0.6786
# Epoch 58/2000
# 57/57 - 5s - loss: 45845.8195 - nossa_metrica: 0.8154 - potvento: 0.9781 - desvpad: 0.7840 - wls: 0.6842 - val_loss: 123193.7539 - val_nossa_metrica: 0.7634 - val_potvento: 0.9420 - val_desvpad: 0.6295 - val_wls: 0.7188
# Epoch 59/2000
# 57/57 - 5s - loss: 44604.0327 - nossa_metrica: 0.8257 - potvento: 0.9803 - desvpad: 0.7829 - wls: 0.7138 - val_loss: 95535.6306 - val_nossa_metrica: 0.7083 - val_potvento: 0.8884 - val_desvpad: 0.5670 - val_wls: 0.6696
# Epoch 60/2000
# 57/57 - 5s - loss: 44562.7792 - nossa_metrica: 0.8216 - potvento: 0.9846 - desvpad: 0.7544 - wls: 0.7259 - val_loss: 113639.2877 - val_nossa_metrica: 0.6979 - val_potvento: 0.8839 - val_desvpad: 0.5625 - val_wls: 0.6473
# Epoch 61/2000
# 57/57 - 5s - loss: 52363.6306 - nossa_metrica: 0.8085 - potvento: 0.9781 - desvpad: 0.7193 - wls: 0.7281 - val_loss: 207098.9177 - val_nossa_metrica: 0.7277 - val_potvento: 0.9464 - val_desvpad: 0.5268 - val_wls: 0.7098
# Epoch 62/2000
# 57/57 - 5s - loss: 78823.3303 - nossa_metrica: 0.7939 - potvento: 0.9616 - desvpad: 0.7083 - wls: 0.7116 - val_loss: 104753.5820 - val_nossa_metrica: 0.7545 - val_potvento: 0.8973 - val_desvpad: 0.5848 - val_wls: 0.7812
# Epoch 63/2000
# 57/57 - 5s - loss: 105776.4330 - nossa_metrica: 0.7814 - potvento: 0.9101 - desvpad: 0.7149 - wls: 0.7193 - val_loss: 374293.1339 - val_nossa_metrica: 0.6741 - val_potvento: 0.7321 - val_desvpad: 0.5491 - val_wls: 0.7411
# Epoch 64/2000
# 57/57 - 5s - loss: 101177.3029 - nossa_metrica: 0.7836 - potvento: 0.9101 - desvpad: 0.7281 - wls: 0.7127 - val_loss: 99467.9191 - val_nossa_metrica: 0.7842 - val_potvento: 0.9509 - val_desvpad: 0.6205 - val_wls: 0.7812
# Epoch 65/2000
# 57/57 - 5s - loss: 58351.7412 - nossa_metrica: 0.7975 - potvento: 0.9496 - desvpad: 0.7412 - wls: 0.7018 - val_loss: 123130.7034 - val_nossa_metrica: 0.6741 - val_potvento: 0.8750 - val_desvpad: 0.5268 - val_wls: 0.6205
# Epoch 66/2000
# 57/57 - 5s - loss: 50337.7277 - nossa_metrica: 0.8037 - potvento: 0.9616 - desvpad: 0.7346 - wls: 0.7149 - val_loss: 89919.3025 - val_nossa_metrica: 0.7307 - val_potvento: 0.8973 - val_desvpad: 0.5759 - val_wls: 0.7188
# Epoch 67/2000
# 57/57 - 5s - loss: 48185.7776 - nossa_metrica: 0.8092 - potvento: 0.9638 - desvpad: 0.7511 - wls: 0.7127 - val_loss: 118379.9191 - val_nossa_metrica: 0.7812 - val_potvento: 0.9241 - val_desvpad: 0.6295 - val_wls: 0.7902
# Epoch 68/2000
# 57/57 - 5s - loss: 47420.2040 - nossa_metrica: 0.8107 - potvento: 0.9627 - desvpad: 0.7522 - wls: 0.7171 - val_loss: 110174.7391 - val_nossa_metrica: 0.7232 - val_potvento: 0.8750 - val_desvpad: 0.5804 - val_wls: 0.7143
# Epoch 69/2000
# 57/57 - 5s - loss: 47682.3116 - nossa_metrica: 0.8077 - potvento: 0.9605 - desvpad: 0.7588 - wls: 0.7039 - val_loss: 77358.1975 - val_nossa_metrica: 0.7217 - val_potvento: 0.8884 - val_desvpad: 0.5714 - val_wls: 0.7054
# Epoch 70/2000
# 57/57 - 5s - loss: 45423.1138 - nossa_metrica: 0.8110 - potvento: 0.9638 - desvpad: 0.7675 - wls: 0.7018 - val_loss: 130911.3664 - val_nossa_metrica: 0.7381 - val_potvento: 0.9554 - val_desvpad: 0.5893 - val_wls: 0.6696
# Epoch 71/2000
# 57/57 - 5s - loss: 47131.9279 - nossa_metrica: 0.8045 - potvento: 0.9616 - desvpad: 0.7566 - wls: 0.6952 - val_loss: 79377.0946 - val_nossa_metrica: 0.7307 - val_potvento: 0.8929 - val_desvpad: 0.5893 - val_wls: 0.7098
# Epoch 72/2000
# 57/57 - 5s - loss: 45399.8795 - nossa_metrica: 0.8132 - potvento: 0.9638 - desvpad: 0.7697 - wls: 0.7061 - val_loss: 100978.4821 - val_nossa_metrica: 0.7381 - val_potvento: 0.8616 - val_desvpad: 0.5938 - val_wls: 0.7589
# Epoch 73/2000
# 57/57 - 5s - loss: 44415.5598 - nossa_metrica: 0.8125 - potvento: 0.9627 - desvpad: 0.7675 - wls: 0.7072 - val_loss: 116772.1694 - val_nossa_metrica: 0.7768 - val_potvento: 0.9286 - val_desvpad: 0.6250 - val_wls: 0.7768
# Epoch 74/2000
# 57/57 - 5s - loss: 44693.7394 - nossa_metrica: 0.8092 - potvento: 0.9605 - desvpad: 0.7719 - wls: 0.6952 - val_loss: 72317.5658 - val_nossa_metrica: 0.7351 - val_potvento: 0.8929 - val_desvpad: 0.6116 - val_wls: 0.7009
# Epoch 75/2000
# 57/57 - 5s - loss: 42680.7196 - nossa_metrica: 0.8099 - potvento: 0.9594 - desvpad: 0.7774 - wls: 0.6930 - val_loss: 112618.5371 - val_nossa_metrica: 0.6875 - val_potvento: 0.8884 - val_desvpad: 0.5580 - val_wls: 0.6161
# Epoch 76/2000
# 57/57 - 5s - loss: 44420.3113 - nossa_metrica: 0.8026 - potvento: 0.9572 - desvpad: 0.7664 - wls: 0.6842 - val_loss: 80536.3736 - val_nossa_metrica: 0.8006 - val_potvento: 0.9643 - val_desvpad: 0.6607 - val_wls: 0.7768
# Epoch 77/2000
# 57/57 - 5s - loss: 43145.0019 - nossa_metrica: 0.8118 - potvento: 0.9594 - desvpad: 0.7829 - wls: 0.6930 - val_loss: 96051.3895 - val_nossa_metrica: 0.7470 - val_potvento: 0.8661 - val_desvpad: 0.6295 - val_wls: 0.7455
# Epoch 78/2000
# 57/57 - 5s - loss: 42175.1051 - nossa_metrica: 0.8187 - potvento: 0.9594 - desvpad: 0.7928 - wls: 0.7039 - val_loss: 101987.3114 - val_nossa_metrica: 0.7158 - val_potvento: 0.8616 - val_desvpad: 0.6071 - val_wls: 0.6786
# Epoch 79/2000
# 57/57 - 5s - loss: 42602.6694 - nossa_metrica: 0.8132 - potvento: 0.9561 - desvpad: 0.7971 - wls: 0.6864 - val_loss: 73547.8405 - val_nossa_metrica: 0.8051 - val_potvento: 0.9643 - val_desvpad: 0.6786 - val_wls: 0.7723
# Epoch 80/2000
# 57/57 - 5s - loss: 40825.7183 - nossa_metrica: 0.8129 - potvento: 0.9594 - desvpad: 0.7993 - wls: 0.6798 - val_loss: 105502.9071 - val_nossa_metrica: 0.6815 - val_potvento: 0.8750 - val_desvpad: 0.5670 - val_wls: 0.6027
# Epoch 81/2000
# 57/57 - 5s - loss: 42669.2270 - nossa_metrica: 0.8041 - potvento: 0.9572 - desvpad: 0.7862 - wls: 0.6689 - val_loss: 68574.1614 - val_nossa_metrica: 0.7440 - val_potvento: 0.8973 - val_desvpad: 0.6161 - val_wls: 0.7188
# Epoch 82/2000
# 57/57 - 5s - loss: 41350.3477 - nossa_metrica: 0.8118 - potvento: 0.9594 - desvpad: 0.8026 - wls: 0.6732 - val_loss: 102402.9512 - val_nossa_metrica: 0.7961 - val_potvento: 0.9241 - val_desvpad: 0.6696 - val_wls: 0.7946
# Epoch 83/2000
# 57/57 - 5s - loss: 40374.2580 - nossa_metrica: 0.8169 - potvento: 0.9594 - desvpad: 0.8114 - wls: 0.6798 - val_loss: 99052.6222 - val_nossa_metrica: 0.6801 - val_potvento: 0.8661 - val_desvpad: 0.6295 - val_wls: 0.5446
# Epoch 84/2000
# 57/57 - 5s - loss: 40677.7781 - nossa_metrica: 0.8125 - potvento: 0.9561 - desvpad: 0.8169 - wls: 0.6645 - val_loss: 62476.1724 - val_nossa_metrica: 0.7515 - val_potvento: 0.8973 - val_desvpad: 0.6295 - val_wls: 0.7277
# Epoch 85/2000
# 57/57 - 5s - loss: 38889.3121 - nossa_metrica: 0.8118 - potvento: 0.9594 - desvpad: 0.8103 - wls: 0.6656 - val_loss: 114764.8697 - val_nossa_metrica: 0.7336 - val_potvento: 0.9464 - val_desvpad: 0.6205 - val_wls: 0.6339
# Epoch 86/2000
# 57/57 - 5s - loss: 40984.6155 - nossa_metrica: 0.8059 - potvento: 0.9572 - desvpad: 0.7993 - wls: 0.6612 - val_loss: 63308.1966 - val_nossa_metrica: 0.7530 - val_potvento: 0.8973 - val_desvpad: 0.6562 - val_wls: 0.7054
# Epoch 87/2000
# 57/57 - 5s - loss: 39764.3364 - nossa_metrica: 0.8143 - potvento: 0.9594 - desvpad: 0.8136 - wls: 0.6700 - val_loss: 87309.5737 - val_nossa_metrica: 0.6994 - val_potvento: 0.8750 - val_desvpad: 0.6473 - val_wls: 0.5759
# Epoch 88/2000
# 57/57 - 5s - loss: 38664.8188 - nossa_metrica: 0.8173 - potvento: 0.9594 - desvpad: 0.8180 - wls: 0.6743 - val_loss: 106677.1733 - val_nossa_metrica: 0.7039 - val_potvento: 0.9286 - val_desvpad: 0.6786 - val_wls: 0.5045
# Epoch 89/2000
# 57/57 - 5s - loss: 38947.7375 - nossa_metrica: 0.8140 - potvento: 0.9561 - desvpad: 0.8180 - wls: 0.6678 - val_loss: 58731.8318 - val_nossa_metrica: 0.7649 - val_potvento: 0.8973 - val_desvpad: 0.6518 - val_wls: 0.7455
# Epoch 90/2000
# 57/57 - 5s - loss: 37057.1427 - nossa_metrica: 0.8114 - potvento: 0.9594 - desvpad: 0.8180 - wls: 0.6568 - val_loss: 98568.1906 - val_nossa_metrica: 0.6875 - val_potvento: 0.8839 - val_desvpad: 0.6071 - val_wls: 0.5714
# Epoch 91/2000
# 57/57 - 5s - loss: 38585.2473 - nossa_metrica: 0.8045 - potvento: 0.9572 - desvpad: 0.8092 - wls: 0.6469 - val_loss: 63791.5993 - val_nossa_metrica: 0.7961 - val_potvento: 0.9643 - val_desvpad: 0.6920 - val_wls: 0.7321
# Epoch 92/2000
# 57/57 - 5s - loss: 37221.9426 - nossa_metrica: 0.8103 - potvento: 0.9594 - desvpad: 0.8169 - wls: 0.6546 - val_loss: 81615.1702 - val_nossa_metrica: 0.6786 - val_potvento: 0.8750 - val_desvpad: 0.6562 - val_wls: 0.5045
# Epoch 93/2000
# 57/57 - 5s - loss: 36394.9811 - nossa_metrica: 0.8191 - potvento: 0.9594 - desvpad: 0.8235 - wls: 0.6743 - val_loss: 91510.8984 - val_nossa_metrica: 0.6577 - val_potvento: 0.8661 - val_desvpad: 0.6384 - val_wls: 0.4688
# Epoch 94/2000
# 57/57 - 5s - loss: 36571.2419 - nossa_metrica: 0.8107 - potvento: 0.9605 - desvpad: 0.8246 - wls: 0.6469 - val_loss: 59938.3545 - val_nossa_metrica: 0.8601 - val_potvento: 0.9643 - val_desvpad: 0.7009 - val_wls: 0.9152
# Epoch 95/2000
# 57/57 - 5s - loss: 34688.9122 - nossa_metrica: 0.8081 - potvento: 0.9627 - desvpad: 0.8246 - wls: 0.6371 - val_loss: 88741.7623 - val_nossa_metrica: 0.6741 - val_potvento: 0.8705 - val_desvpad: 0.6384 - val_wls: 0.5134
# Epoch 96/2000
# 57/57 - 5s - loss: 35922.0769 - nossa_metrica: 0.8048 - potvento: 0.9616 - desvpad: 0.8224 - wls: 0.6305 - val_loss: 54700.0827 - val_nossa_metrica: 0.7173 - val_potvento: 0.8973 - val_desvpad: 0.6384 - val_wls: 0.6161
# Epoch 97/2000
# 57/57 - 5s - loss: 34561.2103 - nossa_metrica: 0.8045 - potvento: 0.9638 - desvpad: 0.8311 - wls: 0.6184 - val_loss: 83793.3622 - val_nossa_metrica: 0.7619 - val_potvento: 0.9375 - val_desvpad: 0.7277 - val_wls: 0.6205
# Epoch 98/2000
# 57/57 - 5s - loss: 33777.3230 - nossa_metrica: 0.8110 - potvento: 0.9638 - desvpad: 0.8355 - wls: 0.6338 - val_loss: 84741.2295 - val_nossa_metrica: 0.6667 - val_potvento: 0.8750 - val_desvpad: 0.6339 - val_wls: 0.4911
# Epoch 99/2000
# 57/57 - 5s - loss: 34420.8585 - nossa_metrica: 0.8092 - potvento: 0.9693 - desvpad: 0.8355 - wls: 0.6228 - val_loss: 49465.0967 - val_nossa_metrica: 0.7426 - val_potvento: 0.8973 - val_desvpad: 0.6741 - val_wls: 0.6562
# Epoch 100/2000
# 57/57 - 5s - loss: 33678.8849 - nossa_metrica: 0.8114 - potvento: 0.9715 - desvpad: 0.8355 - wls: 0.6272 - val_loss: 109699.3189 - val_nossa_metrica: 0.7188 - val_potvento: 0.9509 - val_desvpad: 0.6384 - val_wls: 0.5670
# Epoch 101/2000
# 57/57 - 5s - loss: 36380.4000 - nossa_metrica: 0.8114 - potvento: 0.9704 - desvpad: 0.8268 - wls: 0.6371 - val_loss: 54042.2331 - val_nossa_metrica: 0.7292 - val_potvento: 0.8973 - val_desvpad: 0.7009 - val_wls: 0.5893
# Epoch 102/2000
# 57/57 - 5s - loss: 35306.5145 - nossa_metrica: 0.8085 - potvento: 0.9726 - desvpad: 0.8246 - wls: 0.6283 - val_loss: 75380.4086 - val_nossa_metrica: 0.7812 - val_potvento: 0.8750 - val_desvpad: 0.6696 - val_wls: 0.7991
# Epoch 103/2000
# 57/57 - 5s - loss: 33512.2292 - nossa_metrica: 0.8088 - potvento: 0.9726 - desvpad: 0.8279 - wls: 0.6261 - val_loss: 90841.8112 - val_nossa_metrica: 0.7158 - val_potvento: 0.9464 - val_desvpad: 0.6964 - val_wls: 0.5045
# Epoch 104/2000
# 57/57 - 5s - loss: 34397.9142 - nossa_metrica: 0.8056 - potvento: 0.9693 - desvpad: 0.8268 - wls: 0.6206 - val_loss: 46299.3104 - val_nossa_metrica: 0.6994 - val_potvento: 0.9018 - val_desvpad: 0.7054 - val_wls: 0.4911
# Epoch 105/2000
# 57/57 - 5s - loss: 30703.3105 - nossa_metrica: 0.8059 - potvento: 0.9704 - desvpad: 0.8322 - wls: 0.6151 - val_loss: 79328.5689 - val_nossa_metrica: 0.7024 - val_potvento: 0.8884 - val_desvpad: 0.6562 - val_wls: 0.5625
# Epoch 106/2000
# 57/57 - 5s - loss: 30424.3576 - nossa_metrica: 0.8147 - potvento: 0.9704 - desvpad: 0.8257 - wls: 0.6480 - val_loss: 50334.1581 - val_nossa_metrica: 0.7798 - val_potvento: 0.9643 - val_desvpad: 0.7545 - val_wls: 0.6205
# Epoch 107/2000
# 57/57 - 5s - loss: 29069.0405 - nossa_metrica: 0.8154 - potvento: 0.9726 - desvpad: 0.8279 - wls: 0.6458 - val_loss: 68822.6295 - val_nossa_metrica: 0.7366 - val_potvento: 0.8661 - val_desvpad: 0.6830 - val_wls: 0.6607
# Epoch 108/2000
# 57/57 - 5s - loss: 27349.7517 - nossa_metrica: 0.8268 - potvento: 0.9737 - desvpad: 0.8322 - wls: 0.6743 - val_loss: 68672.9054 - val_nossa_metrica: 0.6964 - val_potvento: 0.8929 - val_desvpad: 0.6696 - val_wls: 0.5268
# Epoch 109/2000
# 57/57 - 5s - loss: 27192.9583 - nossa_metrica: 0.8381 - potvento: 0.9737 - desvpad: 0.8344 - wls: 0.7061 - val_loss: 44739.5608 - val_nossa_metrica: 0.7619 - val_potvento: 0.9688 - val_desvpad: 0.7589 - val_wls: 0.5580
# Epoch 110/2000
# 57/57 - 5s - loss: 25782.7750 - nossa_metrica: 0.8432 - potvento: 0.9770 - desvpad: 0.8366 - wls: 0.7160 - val_loss: 78414.6236 - val_nossa_metrica: 0.7321 - val_potvento: 0.8973 - val_desvpad: 0.6161 - val_wls: 0.6830
# Epoch 111/2000
# 57/57 - 5s - loss: 27671.8709 - nossa_metrica: 0.8450 - potvento: 0.9781 - desvpad: 0.8257 - wls: 0.7314 - val_loss: 48455.7705 - val_nossa_metrica: 0.7619 - val_potvento: 0.9018 - val_desvpad: 0.7054 - val_wls: 0.6786
# Epoch 112/2000
# 57/57 - 5s - loss: 26284.9502 - nossa_metrica: 0.8553 - potvento: 0.9814 - desvpad: 0.8322 - wls: 0.7522 - val_loss: 69658.7492 - val_nossa_metrica: 0.8006 - val_potvento: 0.9420 - val_desvpad: 0.7455 - val_wls: 0.7143
# Epoch 113/2000
# 57/57 - 5s - loss: 24463.2519 - nossa_metrica: 0.8607 - potvento: 0.9825 - desvpad: 0.8366 - wls: 0.7632 - val_loss: 61084.1032 - val_nossa_metrica: 0.8021 - val_potvento: 0.9018 - val_desvpad: 0.6741 - val_wls: 0.8304
# Epoch 114/2000
# 57/57 - 5s - loss: 23462.7254 - nossa_metrica: 0.8677 - potvento: 0.9825 - desvpad: 0.8421 - wls: 0.7785 - val_loss: 37278.8774 - val_nossa_metrica: 0.7530 - val_potvento: 0.9018 - val_desvpad: 0.7098 - val_wls: 0.6473
# Epoch 115/2000
# 57/57 - 5s - loss: 21198.7452 - nossa_metrica: 0.8648 - potvento: 0.9825 - desvpad: 0.8498 - wls: 0.7621 - val_loss: 61947.0971 - val_nossa_metrica: 0.8318 - val_potvento: 0.9777 - val_desvpad: 0.7321 - val_wls: 0.7857
# Epoch 116/2000
# 57/57 - 5s - loss: 21356.1753 - nossa_metrica: 0.8651 - potvento: 0.9825 - desvpad: 0.8465 - wls: 0.7664 - val_loss: 33824.2137 - val_nossa_metrica: 0.7753 - val_potvento: 0.8973 - val_desvpad: 0.7321 - val_wls: 0.6964
# Epoch 117/2000
# 57/57 - 5s - loss: 20309.2030 - nossa_metrica: 0.8699 - potvento: 0.9857 - desvpad: 0.8509 - wls: 0.7730 - val_loss: 49872.7759 - val_nossa_metrica: 0.7560 - val_potvento: 0.8929 - val_desvpad: 0.7009 - val_wls: 0.6741
# Epoch 118/2000
# 57/57 - 5s - loss: 19695.4898 - nossa_metrica: 0.8746 - potvento: 0.9836 - desvpad: 0.8596 - wls: 0.7807 - val_loss: 61718.3916 - val_nossa_metrica: 0.8631 - val_potvento: 0.9643 - val_desvpad: 0.7679 - val_wls: 0.8571
# Epoch 119/2000
# 57/57 - 5s - loss: 19982.6549 - nossa_metrica: 0.8746 - potvento: 0.9814 - desvpad: 0.8607 - wls: 0.7818 - val_loss: 31296.7082 - val_nossa_metrica: 0.7768 - val_potvento: 0.9018 - val_desvpad: 0.7455 - val_wls: 0.6830
# Epoch 120/2000
# 57/57 - 5s - loss: 19088.3039 - nossa_metrica: 0.8717 - potvento: 0.9825 - desvpad: 0.8575 - wls: 0.7752 - val_loss: 59178.1310 - val_nossa_metrica: 0.7723 - val_potvento: 0.9107 - val_desvpad: 0.6741 - val_wls: 0.7321
# Epoch 121/2000
# 57/57 - 5s - loss: 19740.0670 - nossa_metrica: 0.8702 - potvento: 0.9836 - desvpad: 0.8498 - wls: 0.7774 - val_loss: 35079.6810 - val_nossa_metrica: 0.8616 - val_potvento: 0.9821 - val_desvpad: 0.7946 - val_wls: 0.8080
# Epoch 122/2000
# 57/57 - 5s - loss: 19002.4964 - nossa_metrica: 0.8721 - potvento: 0.9846 - desvpad: 0.8542 - wls: 0.7774 - val_loss: 42793.3507 - val_nossa_metrica: 0.7693 - val_potvento: 0.8973 - val_desvpad: 0.7321 - val_wls: 0.6786
# Epoch 123/2000
# 57/57 - 5s - loss: 18309.0515 - nossa_metrica: 0.8754 - potvento: 0.9836 - desvpad: 0.8596 - wls: 0.7829 - val_loss: 58303.2937 - val_nossa_metrica: 0.7902 - val_potvento: 0.8973 - val_desvpad: 0.7188 - val_wls: 0.7545
# Epoch 124/2000
# 57/57 - 5s - loss: 18407.1556 - nossa_metrica: 0.8812 - potvento: 0.9825 - desvpad: 0.8662 - wls: 0.7950 - val_loss: 31297.1681 - val_nossa_metrica: 0.8512 - val_potvento: 0.9732 - val_desvpad: 0.8214 - val_wls: 0.7589
# Epoch 125/2000
# 57/57 - 5s - loss: 17379.2552 - nossa_metrica: 0.8779 - potvento: 0.9825 - desvpad: 0.8640 - wls: 0.7873 - val_loss: 52379.1140 - val_nossa_metrica: 0.7723 - val_potvento: 0.8929 - val_desvpad: 0.7143 - val_wls: 0.7098
# Epoch 126/2000
# 57/57 - 5s - loss: 17911.1960 - nossa_metrica: 0.8765 - potvento: 0.9836 - desvpad: 0.8618 - wls: 0.7840 - val_loss: 31297.2531 - val_nossa_metrica: 0.8110 - val_potvento: 0.9107 - val_desvpad: 0.7411 - val_wls: 0.7812
# Epoch 127/2000
# 57/57 - 5s - loss: 17353.9788 - nossa_metrica: 0.8801 - potvento: 0.9846 - desvpad: 0.8684 - wls: 0.7873 - val_loss: 39145.3608 - val_nossa_metrica: 0.8423 - val_potvento: 0.9732 - val_desvpad: 0.7812 - val_wls: 0.7723
# Epoch 128/2000
# 57/57 - 5s - loss: 16685.3842 - nossa_metrica: 0.8841 - potvento: 0.9836 - desvpad: 0.8783 - wls: 0.7906 - val_loss: 53348.1892 - val_nossa_metrica: 0.7827 - val_potvento: 0.8973 - val_desvpad: 0.7277 - val_wls: 0.7232
# Epoch 129/2000
# 57/57 - 5s - loss: 16703.3294 - nossa_metrica: 0.8889 - potvento: 0.9825 - desvpad: 0.8816 - wls: 0.8026 - val_loss: 27450.2171 - val_nossa_metrica: 0.7604 - val_potvento: 0.9062 - val_desvpad: 0.7634 - val_wls: 0.6116
# Epoch 130/2000
# 57/57 - 5s - loss: 15797.1483 - nossa_metrica: 0.8823 - potvento: 0.9825 - desvpad: 0.8838 - wls: 0.7807 - val_loss: 55577.5078 - val_nossa_metrica: 0.8155 - val_potvento: 0.9688 - val_desvpad: 0.7589 - val_wls: 0.7188
# Epoch 131/2000
# 57/57 - 5s - loss: 16044.4931 - nossa_metrica: 0.8772 - potvento: 0.9846 - desvpad: 0.8794 - wls: 0.7675 - val_loss: 31146.6371 - val_nossa_metrica: 0.8229 - val_potvento: 0.8973 - val_desvpad: 0.7902 - val_wls: 0.7812
# Epoch 132/2000
# 57/57 - 5s - loss: 15358.7456 - nossa_metrica: 0.8801 - potvento: 0.9879 - desvpad: 0.8893 - wls: 0.7632 - val_loss: 32228.0859 - val_nossa_metrica: 0.8140 - val_potvento: 0.9018 - val_desvpad: 0.7545 - val_wls: 0.7857
# Epoch 133/2000
# 57/57 - 5s - loss: 14592.6531 - nossa_metrica: 0.8754 - potvento: 0.9879 - desvpad: 0.8958 - wls: 0.7423 - val_loss: 53360.3677 - val_nossa_metrica: 0.8095 - val_potvento: 0.9688 - val_desvpad: 0.7902 - val_wls: 0.6696
# Epoch 134/2000
# 57/57 - 5s - loss: 14424.2310 - nossa_metrica: 0.8695 - potvento: 0.9868 - desvpad: 0.8936 - wls: 0.7281 - val_loss: 24464.1434 - val_nossa_metrica: 0.7351 - val_potvento: 0.9107 - val_desvpad: 0.7946 - val_wls: 0.5000
# Epoch 135/2000
# 57/57 - 5s - loss: 13581.5672 - nossa_metrica: 0.8571 - potvento: 0.9868 - desvpad: 0.8925 - wls: 0.6919 - val_loss: 42508.8110 - val_nossa_metrica: 0.7143 - val_potvento: 0.9018 - val_desvpad: 0.7277 - val_wls: 0.5134
# Epoch 136/2000
# 57/57 - 5s - loss: 13676.1325 - nossa_metrica: 0.8454 - potvento: 0.9879 - desvpad: 0.8904 - wls: 0.6579 - val_loss: 30752.6811 - val_nossa_metrica: 0.8497 - val_potvento: 0.9643 - val_desvpad: 0.8661 - val_wls: 0.7188
# Epoch 137/2000
# 57/57 - 5s - loss: 13005.2144 - nossa_metrica: 0.8352 - potvento: 0.9879 - desvpad: 0.8980 - wls: 0.6195 - val_loss: 25372.8167 - val_nossa_metrica: 0.7217 - val_potvento: 0.9152 - val_desvpad: 0.7634 - val_wls: 0.4866
# Epoch 138/2000
# 57/57 - 5s - loss: 12328.2246 - nossa_metrica: 0.8129 - potvento: 0.9879 - desvpad: 0.9090 - wls: 0.5417 - val_loss: 40793.9396 - val_nossa_metrica: 0.7143 - val_potvento: 0.9062 - val_desvpad: 0.7679 - val_wls: 0.4688
# Epoch 139/2000
# 57/57 - 5s - loss: 12007.1184 - nossa_metrica: 0.8103 - potvento: 0.9868 - desvpad: 0.9211 - wls: 0.5230 - val_loss: 24529.6549 - val_nossa_metrica: 0.7827 - val_potvento: 0.9821 - val_desvpad: 0.8661 - val_wls: 0.5000
# Epoch 140/2000
# 57/57 - 5s - loss: 11327.6539 - nossa_metrica: 0.8169 - potvento: 0.9868 - desvpad: 0.9156 - wls: 0.5482 - val_loss: 32479.0970 - val_nossa_metrica: 0.6994 - val_potvento: 0.8929 - val_desvpad: 0.7679 - val_wls: 0.4375
# Epoch 141/2000
# 57/57 - 5s - loss: 11353.6345 - nossa_metrica: 0.8311 - potvento: 0.9890 - desvpad: 0.9134 - wls: 0.5910 - val_loss: 26896.4787 - val_nossa_metrica: 0.7381 - val_potvento: 0.9018 - val_desvpad: 0.8080 - val_wls: 0.5045
# Epoch 142/2000
# 57/57 - 5s - loss: 10743.5539 - nossa_metrica: 0.8421 - potvento: 0.9912 - desvpad: 0.9189 - wls: 0.6162 - val_loss: 23338.5681 - val_nossa_metrica: 0.7813 - val_potvento: 0.9777 - val_desvpad: 0.8616 - val_wls: 0.5045
# Epoch 143/2000
# 57/57 - 5s - loss: 10285.9403 - nossa_metrica: 0.8454 - potvento: 0.9923 - desvpad: 0.9265 - wls: 0.6173 - val_loss: 32169.7698 - val_nossa_metrica: 0.7188 - val_potvento: 0.9062 - val_desvpad: 0.7902 - val_wls: 0.4598
# Epoch 144/2000
# 57/57 - 5s - loss: 10044.4481 - nossa_metrica: 0.8326 - potvento: 0.9912 - desvpad: 0.9287 - wls: 0.5779 - val_loss: 20850.1314 - val_nossa_metrica: 0.7277 - val_potvento: 0.9107 - val_desvpad: 0.8080 - val_wls: 0.4643
# Epoch 145/2000
# 57/57 - 5s - loss: 9550.2293 - nossa_metrica: 0.8180 - potvento: 0.9912 - desvpad: 0.9243 - wls: 0.5384 - val_loss: 29402.9641 - val_nossa_metrica: 0.7723 - val_potvento: 0.9688 - val_desvpad: 0.8482 - val_wls: 0.5000
# Epoch 146/2000
# 57/57 - 5s - loss: 9555.8842 - nossa_metrica: 0.8268 - potvento: 0.9912 - desvpad: 0.9265 - wls: 0.5625 - val_loss: 22753.5827 - val_nossa_metrica: 0.7842 - val_potvento: 0.8973 - val_desvpad: 0.8170 - val_wls: 0.6384
# Epoch 147/2000
# 57/57 - 5s - loss: 9086.8409 - nossa_metrica: 0.8297 - potvento: 0.9923 - desvpad: 0.9320 - wls: 0.5647 - val_loss: 18325.1998 - val_nossa_metrica: 0.7336 - val_potvento: 0.9107 - val_desvpad: 0.8214 - val_wls: 0.4688
# Epoch 148/2000
# 57/57 - 5s - loss: 8758.9979 - nossa_metrica: 0.8406 - potvento: 0.9923 - desvpad: 0.9364 - wls: 0.5932 - val_loss: 28636.9484 - val_nossa_metrica: 0.7783 - val_potvento: 0.9777 - val_desvpad: 0.8527 - val_wls: 0.5045
# Epoch 149/2000
# 57/57 - 5s - loss: 8538.6905 - nossa_metrica: 0.8443 - potvento: 0.9912 - desvpad: 0.9375 - wls: 0.6042 - val_loss: 18191.5133 - val_nossa_metrica: 0.7440 - val_potvento: 0.9152 - val_desvpad: 0.8259 - val_wls: 0.4911
# Epoch 150/2000
# 57/57 - 5s - loss: 8189.7689 - nossa_metrica: 0.8352 - potvento: 0.9912 - desvpad: 0.9342 - wls: 0.5800 - val_loss: 21921.8680 - val_nossa_metrica: 0.7232 - val_potvento: 0.9062 - val_desvpad: 0.7946 - val_wls: 0.4688
# Epoch 151/2000
# 57/57 - 5s - loss: 8302.0416 - nossa_metrica: 0.8304 - potvento: 0.9923 - desvpad: 0.9254 - wls: 0.5735 - val_loss: 21301.6003 - val_nossa_metrica: 0.8318 - val_potvento: 0.9777 - val_desvpad: 0.8929 - val_wls: 0.6250
# Epoch 152/2000
# 57/57 - 5s - loss: 7901.5307 - nossa_metrica: 0.8176 - potvento: 0.9934 - desvpad: 0.9221 - wls: 0.5373 - val_loss: 16310.6832 - val_nossa_metrica: 0.7485 - val_potvento: 0.9107 - val_desvpad: 0.8438 - val_wls: 0.4911
# Epoch 153/2000
# 57/57 - 5s - loss: 7651.2337 - nossa_metrica: 0.8249 - potvento: 0.9945 - desvpad: 0.9298 - wls: 0.5504 - val_loss: 22440.7031 - val_nossa_metrica: 0.7307 - val_potvento: 0.9107 - val_desvpad: 0.8125 - val_wls: 0.4688
# Epoch 154/2000
# 57/57 - 5s - loss: 7517.6089 - nossa_metrica: 0.8337 - potvento: 0.9956 - desvpad: 0.9375 - wls: 0.5680 - val_loss: 18830.0351 - val_nossa_metrica: 0.7902 - val_potvento: 0.9821 - val_desvpad: 0.8839 - val_wls: 0.5045
# Epoch 155/2000
# 57/57 - 5s - loss: 7265.3218 - nossa_metrica: 0.8293 - potvento: 0.9956 - desvpad: 0.9331 - wls: 0.5592 - val_loss: 17396.7266 - val_nossa_metrica: 0.7262 - val_potvento: 0.9107 - val_desvpad: 0.8214 - val_wls: 0.4464
# Epoch 156/2000
# 57/57 - 5s - loss: 7344.2647 - nossa_metrica: 0.8322 - potvento: 0.9956 - desvpad: 0.9265 - wls: 0.5746 - val_loss: 17465.9340 - val_nossa_metrica: 0.7917 - val_potvento: 0.9062 - val_desvpad: 0.8304 - val_wls: 0.6384
# Epoch 157/2000
# 57/57 - 5s - loss: 7080.2773 - nossa_metrica: 0.8253 - potvento: 0.9956 - desvpad: 0.9254 - wls: 0.5548 - val_loss: 15889.4565 - val_nossa_metrica: 0.7976 - val_potvento: 0.9866 - val_desvpad: 0.9018 - val_wls: 0.5045
# Epoch 158/2000
# 57/57 - 5s - loss: 6910.0515 - nossa_metrica: 0.8246 - potvento: 0.9967 - desvpad: 0.9287 - wls: 0.5482 - val_loss: 19613.3885 - val_nossa_metrica: 0.7247 - val_potvento: 0.9107 - val_desvpad: 0.8170 - val_wls: 0.4464
# Epoch 159/2000
# 57/57 - 5s - loss: 6822.5185 - nossa_metrica: 0.8235 - potvento: 0.9956 - desvpad: 0.9353 - wls: 0.5395 - val_loss: 17741.3706 - val_nossa_metrica: 0.7307 - val_potvento: 0.9152 - val_desvpad: 0.8080 - val_wls: 0.4688
# Epoch 160/2000
# 57/57 - 5s - loss: 6654.7368 - nossa_metrica: 0.8231 - potvento: 0.9956 - desvpad: 0.9320 - wls: 0.5417 - val_loss: 17061.4357 - val_nossa_metrica: 0.7902 - val_potvento: 0.9821 - val_desvpad: 0.8884 - val_wls: 0.5000
# Epoch 161/2000
# 57/57 - 5s - loss: 6760.7335 - nossa_metrica: 0.8304 - potvento: 0.9989 - desvpad: 0.9276 - wls: 0.5647 - val_loss: 15466.8866 - val_nossa_metrica: 0.7902 - val_potvento: 0.9062 - val_desvpad: 0.8438 - val_wls: 0.6205
# Epoch 162/2000
# 57/57 - 5s - loss: 6541.8300 - nossa_metrica: 0.8253 - potvento: 1.0000 - desvpad: 0.9276 - wls: 0.5482 - val_loss: 14597.5688 - val_nossa_metrica: 0.7411 - val_potvento: 0.9152 - val_desvpad: 0.8393 - val_wls: 0.4688
# Epoch 163/2000
# 57/57 - 5s - loss: 6472.3258 - nossa_metrica: 0.8282 - potvento: 1.0000 - desvpad: 0.9320 - wls: 0.5526 - val_loss: 20406.7231 - val_nossa_metrica: 0.7946 - val_potvento: 0.9821 - val_desvpad: 0.8973 - val_wls: 0.5045
# Epoch 164/2000
# 57/57 - 5s - loss: 6287.2903 - nossa_metrica: 0.8315 - potvento: 1.0000 - desvpad: 0.9419 - wls: 0.5526 - val_loss: 16022.7658 - val_nossa_metrica: 0.7396 - val_potvento: 0.9107 - val_desvpad: 0.8170 - val_wls: 0.4911
# Epoch 165/2000
# 57/57 - 5s - loss: 6307.4478 - nossa_metrica: 0.8242 - potvento: 1.0000 - desvpad: 0.9364 - wls: 0.5362 - val_loss: 14144.9290 - val_nossa_metrica: 0.7336 - val_potvento: 0.9107 - val_desvpad: 0.8259 - val_wls: 0.4643
# Epoch 166/2000
# 57/57 - 5s - loss: 6252.7046 - nossa_metrica: 0.8275 - potvento: 1.0000 - desvpad: 0.9353 - wls: 0.5471 - val_loss: 15837.4162 - val_nossa_metrica: 0.8244 - val_potvento: 0.9821 - val_desvpad: 0.9062 - val_wls: 0.5848
# Epoch 167/2000
# 57/57 - 5s - loss: 6045.4256 - nossa_metrica: 0.8151 - potvento: 1.0000 - desvpad: 0.9342 - wls: 0.5110 - val_loss: 13116.9403 - val_nossa_metrica: 0.7530 - val_potvento: 0.9152 - val_desvpad: 0.8527 - val_wls: 0.4911
# Epoch 168/2000
# 57/57 - 5s - loss: 5915.5630 - nossa_metrica: 0.8173 - potvento: 1.0000 - desvpad: 0.9364 - wls: 0.5154 - val_loss: 19201.4422 - val_nossa_metrica: 0.7366 - val_potvento: 0.9152 - val_desvpad: 0.8304 - val_wls: 0.4643
# Epoch 169/2000
# 57/57 - 5s - loss: 5843.7957 - nossa_metrica: 0.8187 - potvento: 0.9956 - desvpad: 0.9430 - wls: 0.5175 - val_loss: 15727.5935 - val_nossa_metrica: 0.7887 - val_potvento: 0.9821 - val_desvpad: 0.8795 - val_wls: 0.5045
# Epoch 170/2000
# 57/57 - 5s - loss: 5775.7245 - nossa_metrica: 0.8224 - potvento: 0.9912 - desvpad: 0.9419 - wls: 0.5340 - val_loss: 13151.2653 - val_nossa_metrica: 0.7321 - val_potvento: 0.9107 - val_desvpad: 0.8438 - val_wls: 0.4420
# Epoch 171/2000
# 57/57 - 5s - loss: 5819.2302 - nossa_metrica: 0.8275 - potvento: 0.9923 - desvpad: 0.9397 - wls: 0.5504 - val_loss: 14916.7900 - val_nossa_metrica: 0.7723 - val_potvento: 0.9107 - val_desvpad: 0.8348 - val_wls: 0.5714
# Epoch 172/2000
# 57/57 - 5s - loss: 5680.0648 - nossa_metrica: 0.8158 - potvento: 0.9890 - desvpad: 0.9375 - wls: 0.5208 - val_loss: 13396.2135 - val_nossa_metrica: 0.8021 - val_potvento: 0.9866 - val_desvpad: 0.9152 - val_wls: 0.5045
# Epoch 173/2000
# 57/57 - 5s - loss: 5480.7994 - nossa_metrica: 0.8180 - potvento: 0.9912 - desvpad: 0.9419 - wls: 0.5208 - val_loss: 17044.3269 - val_nossa_metrica: 0.7336 - val_potvento: 0.9152 - val_desvpad: 0.8393 - val_wls: 0.4464
# Epoch 174/2000
# 57/57 - 5s - loss: 5481.9892 - nossa_metrica: 0.8165 - potvento: 0.9868 - desvpad: 0.9452 - wls: 0.5175 - val_loss: 15800.6757 - val_nossa_metrica: 0.7292 - val_potvento: 0.9107 - val_desvpad: 0.8080 - val_wls: 0.4688
# Epoch 175/2000
# 57/57 - 5s - loss: 5356.1746 - nossa_metrica: 0.8147 - potvento: 0.9901 - desvpad: 0.9430 - wls: 0.5110 - val_loss: 13291.8847 - val_nossa_metrica: 0.7961 - val_potvento: 0.9866 - val_desvpad: 0.9062 - val_wls: 0.4955
# Epoch 176/2000
# 57/57 - 5s - loss: 5441.2125 - nossa_metrica: 0.8205 - potvento: 0.9890 - desvpad: 0.9397 - wls: 0.5329 - val_loss: 13920.0199 - val_nossa_metrica: 0.7649 - val_potvento: 0.9107 - val_desvpad: 0.8482 - val_wls: 0.5357
# Epoch 177/2000
# 57/57 - 5s - loss: 5345.0561 - nossa_metrica: 0.8129 - potvento: 0.9857 - desvpad: 0.9386 - wls: 0.5143 - val_loss: 12324.2709 - val_nossa_metrica: 0.7440 - val_potvento: 0.9152 - val_desvpad: 0.8482 - val_wls: 0.4688
# Epoch 178/2000
# 57/57 - 5s - loss: 5136.1661 - nossa_metrica: 0.8242 - potvento: 0.9879 - desvpad: 0.9463 - wls: 0.5384 - val_loss: 19515.5277 - val_nossa_metrica: 0.7887 - val_potvento: 0.9866 - val_desvpad: 0.8795 - val_wls: 0.5000
# Epoch 179/2000
# 57/57 - 5s - loss: 5184.0289 - nossa_metrica: 0.8220 - potvento: 0.9868 - desvpad: 0.9496 - wls: 0.5296 - val_loss: 13620.5458 - val_nossa_metrica: 0.7426 - val_potvento: 0.9107 - val_desvpad: 0.8259 - val_wls: 0.4911
# Epoch 180/2000
# 57/57 - 5s - loss: 5040.3867 - nossa_metrica: 0.8198 - potvento: 0.9901 - desvpad: 0.9485 - wls: 0.5208 - val_loss: 11970.3499 - val_nossa_metrica: 0.7455 - val_potvento: 0.9152 - val_desvpad: 0.8571 - val_wls: 0.4643
# Epoch 181/2000
# 57/57 - 5s - loss: 5144.7917 - nossa_metrica: 0.8242 - potvento: 0.9923 - desvpad: 0.9441 - wls: 0.5362 - val_loss: 15721.5765 - val_nossa_metrica: 0.8214 - val_potvento: 0.9821 - val_desvpad: 0.9152 - val_wls: 0.5670
# Epoch 182/2000
# 57/57 - 5s - loss: 4923.3583 - nossa_metrica: 0.8147 - potvento: 0.9912 - desvpad: 0.9441 - wls: 0.5088 - val_loss: 11005.7265 - val_nossa_metrica: 0.7574 - val_potvento: 0.9152 - val_desvpad: 0.8661 - val_wls: 0.4911
# Epoch 183/2000
# 57/57 - 5s - loss: 4928.3094 - nossa_metrica: 0.8165 - potvento: 0.9923 - desvpad: 0.9430 - wls: 0.5143 - val_loss: 17022.8301 - val_nossa_metrica: 0.7351 - val_potvento: 0.9152 - val_desvpad: 0.8304 - val_wls: 0.4598
# Epoch 184/2000
# 57/57 - 5s - loss: 4922.2255 - nossa_metrica: 0.8213 - potvento: 0.9912 - desvpad: 0.9474 - wls: 0.5252 - val_loss: 17092.2021 - val_nossa_metrica: 0.7872 - val_potvento: 0.9866 - val_desvpad: 0.8705 - val_wls: 0.5045
# Epoch 185/2000
# 57/57 - 5s - loss: 4841.0468 - nossa_metrica: 0.8213 - potvento: 0.9901 - desvpad: 0.9485 - wls: 0.5252 - val_loss: 10955.0215 - val_nossa_metrica: 0.7411 - val_potvento: 0.9152 - val_desvpad: 0.8661 - val_wls: 0.4420
# Epoch 186/2000
# 57/57 - 5s - loss: 4979.5030 - nossa_metrica: 0.8246 - potvento: 0.9923 - desvpad: 0.9397 - wls: 0.5417 - val_loss: 15394.9674 - val_nossa_metrica: 0.7545 - val_potvento: 0.9107 - val_desvpad: 0.8304 - val_wls: 0.5223
# Epoch 187/2000
# 57/57 - 5s - loss: 4616.5649 - nossa_metrica: 0.8143 - potvento: 0.9912 - desvpad: 0.9430 - wls: 0.5088 - val_loss: 12306.9512 - val_nossa_metrica: 0.8051 - val_potvento: 0.9866 - val_desvpad: 0.9241 - val_wls: 0.5045
# Epoch 188/2000
# 57/57 - 5s - loss: 4810.3836 - nossa_metrica: 0.8140 - potvento: 0.9923 - desvpad: 0.9408 - wls: 0.5088 - val_loss: 17851.5280 - val_nossa_metrica: 0.7173 - val_potvento: 0.9152 - val_desvpad: 0.7991 - val_wls: 0.4375
# Epoch 189/2000
# 57/57 - 5s - loss: 4436.5969 - nossa_metrica: 0.8202 - potvento: 0.9912 - desvpad: 0.9485 - wls: 0.5208 - val_loss: 14174.7506 - val_nossa_metrica: 0.7336 - val_potvento: 0.9152 - val_desvpad: 0.8170 - val_wls: 0.4688
# Epoch 190/2000
# 57/57 - 5s - loss: 4718.9472 - nossa_metrica: 0.8183 - potvento: 0.9912 - desvpad: 0.9452 - wls: 0.5186 - val_loss: 11732.2111 - val_nossa_metrica: 0.8021 - val_potvento: 0.9866 - val_desvpad: 0.9241 - val_wls: 0.4955
# Epoch 191/2000
# 57/57 - 5s - loss: 4452.1732 - nossa_metrica: 0.8315 - potvento: 0.9923 - desvpad: 0.9463 - wls: 0.5559 - val_loss: 12746.8803 - val_nossa_metrica: 0.7708 - val_potvento: 0.9107 - val_desvpad: 0.8527 - val_wls: 0.5491
# Epoch 192/2000
# 57/57 - 5s - loss: 4665.7243 - nossa_metrica: 0.8216 - potvento: 0.9912 - desvpad: 0.9397 - wls: 0.5340 - val_loss: 11630.7682 - val_nossa_metrica: 0.7455 - val_potvento: 0.9152 - val_desvpad: 0.8527 - val_wls: 0.4688
# Epoch 193/2000
# 57/57 - 5s - loss: 4204.5931 - nossa_metrica: 0.8257 - potvento: 0.9956 - desvpad: 0.9474 - wls: 0.5340 - val_loss: 19606.0828 - val_nossa_metrica: 0.7872 - val_potvento: 0.9866 - val_desvpad: 0.8750 - val_wls: 0.5000
# Epoch 194/2000
# 57/57 - 5s - loss: 4418.5391 - nossa_metrica: 0.8238 - potvento: 0.9967 - desvpad: 0.9485 - wls: 0.5263 - val_loss: 13564.7222 - val_nossa_metrica: 0.7485 - val_potvento: 0.9196 - val_desvpad: 0.8348 - val_wls: 0.4911
# Epoch 195/2000
# 57/57 - 5s - loss: 4513.5115 - nossa_metrica: 0.8187 - potvento: 0.9956 - desvpad: 0.9452 - wls: 0.5154 - val_loss: 10595.1642 - val_nossa_metrica: 0.7440 - val_potvento: 0.9107 - val_desvpad: 0.8616 - val_wls: 0.4598
# Epoch 196/2000
# 57/57 - 5s - loss: 4588.4250 - nossa_metrica: 0.8257 - potvento: 0.9967 - desvpad: 0.9397 - wls: 0.5406 - val_loss: 15450.7401 - val_nossa_metrica: 0.8185 - val_potvento: 0.9866 - val_desvpad: 0.8884 - val_wls: 0.5804
# Epoch 197/2000
# 57/57 - 5s - loss: 4215.3987 - nossa_metrica: 0.8216 - potvento: 1.0000 - desvpad: 0.9408 - wls: 0.5241 - val_loss: 8865.8514 - val_nossa_metrica: 0.7560 - val_potvento: 0.9196 - val_desvpad: 0.8571 - val_wls: 0.4911
# Epoch 198/2000
# 57/57 - 5s - loss: 4112.6372 - nossa_metrica: 0.8311 - potvento: 1.0000 - desvpad: 0.9485 - wls: 0.5450 - val_loss: 14594.2259 - val_nossa_metrica: 0.7336 - val_potvento: 0.9152 - val_desvpad: 0.8214 - val_wls: 0.4643
# Epoch 199/2000
# 57/57 - 5s - loss: 4047.5868 - nossa_metrica: 0.8406 - potvento: 1.0000 - desvpad: 0.9572 - wls: 0.5647 - val_loss: 12319.4782 - val_nossa_metrica: 0.7991 - val_potvento: 0.9911 - val_desvpad: 0.9018 - val_wls: 0.5045
# Epoch 200/2000
# 57/57 - 5s - loss: 3999.2716 - nossa_metrica: 0.8366 - potvento: 1.0000 - desvpad: 0.9561 - wls: 0.5537 - val_loss: 9139.6239 - val_nossa_metrica: 0.7426 - val_potvento: 0.9196 - val_desvpad: 0.8661 - val_wls: 0.4420
# Epoch 201/2000
# 57/57 - 5s - loss: 4157.8701 - nossa_metrica: 0.8352 - potvento: 1.0000 - desvpad: 0.9485 - wls: 0.5570 - val_loss: 11477.1562 - val_nossa_metrica: 0.7664 - val_potvento: 0.9107 - val_desvpad: 0.8393 - val_wls: 0.5491
# Epoch 202/2000
# 57/57 - 5s - loss: 4092.2251 - nossa_metrica: 0.8235 - potvento: 1.0000 - desvpad: 0.9463 - wls: 0.5241 - val_loss: 9773.0425 - val_nossa_metrica: 0.8065 - val_potvento: 0.9911 - val_desvpad: 0.9241 - val_wls: 0.5045
# Epoch 203/2000
# 57/57 - 5s - loss: 3863.5553 - nossa_metrica: 0.8260 - potvento: 1.0000 - desvpad: 0.9507 - wls: 0.5274 - val_loss: 12146.0838 - val_nossa_metrica: 0.7321 - val_potvento: 0.9152 - val_desvpad: 0.8393 - val_wls: 0.4420
# Epoch 204/2000
# 57/57 - 5s - loss: 3888.9979 - nossa_metrica: 0.8279 - potvento: 1.0000 - desvpad: 0.9550 - wls: 0.5285 - val_loss: 12313.6625 - val_nossa_metrica: 0.7411 - val_potvento: 0.9196 - val_desvpad: 0.8348 - val_wls: 0.4688
# Epoch 205/2000
# 57/57 - 5s - loss: 4083.8877 - nossa_metrica: 0.8246 - potvento: 1.0000 - desvpad: 0.9529 - wls: 0.5208 - val_loss: 11485.8697 - val_nossa_metrica: 0.8006 - val_potvento: 0.9911 - val_desvpad: 0.9152 - val_wls: 0.4955
# Epoch 206/2000
# ...
# Epoch 1933/2000
# 57/57 - 5s - loss: 753.2223 - nossa_metrica: 0.8739 - potvento: 0.9934 - desvpad: 0.9868 - wls: 0.6414 - val_loss: 8027.8043 - val_nossa_metrica: 0.8408 - val_potvento: 0.9821 - val_desvpad: 0.9196 - val_wls: 0.6205
# Epoch 1934/2000
# 57/57 - 5s - loss: 772.6268 - nossa_metrica: 0.9097 - potvento: 0.9912 - desvpad: 0.9879 - wls: 0.7500 - val_loss: 4978.3521 - val_nossa_metrica: 0.7545 - val_potvento: 0.9152 - val_desvpad: 0.8571 - val_wls: 0.4911
# Epoch 1935/2000
# 57/57 - 5s - loss: 758.8142 - nossa_metrica: 0.8545 - potvento: 0.9912 - desvpad: 0.9890 - wls: 0.5833 - val_loss: 5203.7040 - val_nossa_metrica: 0.7500 - val_potvento: 0.9152 - val_desvpad: 0.8661 - val_wls: 0.4688
# Epoch 1936/2000
# 57/57 - 5s - loss: 776.2694 - nossa_metrica: 0.8260 - potvento: 0.9912 - desvpad: 0.9868 - wls: 0.5000 - val_loss: 5838.1102 - val_nossa_metrica: 0.8080 - val_potvento: 0.9911 - val_desvpad: 0.9286 - val_wls: 0.5045
# Epoch 1937/2000
# 57/57 - 5s - loss: 770.2720 - nossa_metrica: 0.8823 - potvento: 0.9912 - desvpad: 0.9868 - wls: 0.6689 - val_loss: 5043.1461 - val_nossa_metrica: 0.8229 - val_potvento: 0.9196 - val_desvpad: 0.8661 - val_wls: 0.6830
# Epoch 1938/2000
# 57/57 - 5s - loss: 752.7851 - nossa_metrica: 0.9053 - potvento: 0.9934 - desvpad: 0.9868 - wls: 0.7357 - val_loss: 7352.6889 - val_nossa_metrica: 0.7455 - val_potvento: 0.9107 - val_desvpad: 0.8571 - val_wls: 0.4688
# Epoch 1939/2000
# 57/57 - 5s - loss: 775.5348 - nossa_metrica: 0.8516 - potvento: 0.9912 - desvpad: 0.9890 - wls: 0.5746 - val_loss: 5438.0989 - val_nossa_metrica: 0.8051 - val_potvento: 0.9866 - val_desvpad: 0.9241 - val_wls: 0.5045
# Epoch 1940/2000
# 57/57 - 5s - loss: 769.5915 - nossa_metrica: 0.8399 - potvento: 0.9912 - desvpad: 0.9923 - wls: 0.5362 - val_loss: 4989.9525 - val_nossa_metrica: 0.7649 - val_potvento: 0.9152 - val_desvpad: 0.8661 - val_wls: 0.5134
# Epoch 1941/2000
# 57/57 - 5s - loss: 791.6740 - nossa_metrica: 0.8808 - potvento: 0.9912 - desvpad: 0.9901 - wls: 0.6612 - val_loss: 5383.7391 - val_nossa_metrica: 0.7515 - val_potvento: 0.9196 - val_desvpad: 0.8661 - val_wls: 0.4688
# Epoch 1942/2000
# 57/57 - 5s - loss: 781.0968 - nossa_metrica: 0.8929 - potvento: 0.9912 - desvpad: 0.9868 - wls: 0.7007 - val_loss: 5722.5467 - val_nossa_metrica: 0.8065 - val_potvento: 0.9866 - val_desvpad: 0.9286 - val_wls: 0.5045
# Epoch 1943/2000
# 57/57 - 4s - loss: 758.8526 - nossa_metrica: 0.8476 - potvento: 0.9934 - desvpad: 0.9868 - wls: 0.5625 - val_loss: 7468.6158 - val_nossa_metrica: 0.7515 - val_potvento: 0.9107 - val_desvpad: 0.8527 - val_wls: 0.4911
# Epoch 1944/2000
# 57/57 - 5s - loss: 777.3618 - nossa_metrica: 0.8311 - potvento: 0.9923 - desvpad: 0.9879 - wls: 0.5132 - val_loss: 4911.3158 - val_nossa_metrica: 0.7485 - val_potvento: 0.9152 - val_desvpad: 0.8616 - val_wls: 0.4688
# Epoch 1945/2000
# 57/57 - 5s - loss: 757.0880 - nossa_metrica: 0.8947 - potvento: 0.9934 - desvpad: 0.9901 - wls: 0.7007 - val_loss: 5613.8727 - val_nossa_metrica: 0.9390 - val_potvento: 0.9866 - val_desvpad: 0.9286 - val_wls: 0.9018
# Epoch 1946/2000
# 57/57 - 5s - loss: 792.0495 - nossa_metrica: 0.8823 - potvento: 0.9912 - desvpad: 0.9890 - wls: 0.6667 - val_loss: 5089.7973 - val_nossa_metrica: 0.7679 - val_potvento: 0.9196 - val_desvpad: 0.8661 - val_wls: 0.5179
# Epoch 1947/2000
# 57/57 - 5s - loss: 799.3019 - nossa_metrica: 0.8476 - potvento: 0.9912 - desvpad: 0.9912 - wls: 0.5603 - val_loss: 5483.0429 - val_nossa_metrica: 0.7500 - val_potvento: 0.9152 - val_desvpad: 0.8661 - val_wls: 0.4688
# Epoch 1948/2000
# 57/57 - 5s - loss: 769.4681 - nossa_metrica: 0.8385 - potvento: 0.9934 - desvpad: 0.9868 - wls: 0.5351 - val_loss: 8268.9222 - val_nossa_metrica: 0.8006 - val_potvento: 0.9777 - val_desvpad: 0.9196 - val_wls: 0.5045
# Epoch 1949/2000
# 57/57 - 5s - loss: 783.2107 - nossa_metrica: 0.8929 - potvento: 0.9912 - desvpad: 0.9879 - wls: 0.6996 - val_loss: 4945.7716 - val_nossa_metrica: 0.8616 - val_potvento: 0.9152 - val_desvpad: 0.8571 - val_wls: 0.8125
# Epoch 1950/2000
# 57/57 - 5s - loss: 769.1190 - nossa_metrica: 0.8867 - potvento: 0.9912 - desvpad: 0.9890 - wls: 0.6798 - val_loss: 5195.3746 - val_nossa_metrica: 0.7500 - val_potvento: 0.9152 - val_desvpad: 0.8661 - val_wls: 0.4688
# Epoch 1951/2000
# 57/57 - 5s - loss: 791.8335 - nossa_metrica: 0.8439 - potvento: 0.9912 - desvpad: 0.9890 - wls: 0.5515 - val_loss: 5800.2031 - val_nossa_metrica: 0.8051 - val_potvento: 0.9911 - val_desvpad: 0.9286 - val_wls: 0.4955
# Epoch 1952/2000
# 57/57 - 5s - loss: 784.2430 - nossa_metrica: 0.8333 - potvento: 0.9923 - desvpad: 0.9912 - wls: 0.5164 - val_loss: 5157.5733 - val_nossa_metrica: 0.7574 - val_potvento: 0.9152 - val_desvpad: 0.8661 - val_wls: 0.4911
# Epoch 1953/2000
# 57/57 - 5s - loss: 763.6408 - nossa_metrica: 0.9017 - potvento: 0.9934 - desvpad: 0.9868 - wls: 0.7248 - val_loss: 7564.7942 - val_nossa_metrica: 0.8705 - val_potvento: 0.9107 - val_desvpad: 0.8571 - val_wls: 0.8438
# Epoch 1954/2000
# 57/57 - 5s - loss: 788.1943 - nossa_metrica: 0.8779 - potvento: 0.9912 - desvpad: 0.9879 - wls: 0.6546 - val_loss: 5493.8171 - val_nossa_metrica: 0.8051 - val_potvento: 0.9866 - val_desvpad: 0.9241 - val_wls: 0.5045
# Epoch 1955/2000
# 57/57 - 5s - loss: 778.3965 - nossa_metrica: 0.8450 - potvento: 0.9923 - desvpad: 0.9890 - wls: 0.5537 - val_loss: 5036.1651 - val_nossa_metrica: 0.7574 - val_potvento: 0.9152 - val_desvpad: 0.8661 - val_wls: 0.4911
# Epoch 1956/2000
# 57/57 - 5s - loss: 787.3885 - nossa_metrica: 0.8293 - potvento: 0.9934 - desvpad: 0.9868 - wls: 0.5077 - val_loss: 5657.1329 - val_nossa_metrica: 0.7515 - val_potvento: 0.9152 - val_desvpad: 0.8705 - val_wls: 0.4688
# Epoch 1957/2000
# 57/57 - 5s - loss: 790.2467 - nossa_metrica: 0.9083 - potvento: 0.9923 - desvpad: 0.9868 - wls: 0.7456 - val_loss: 5725.4177 - val_nossa_metrica: 0.8467 - val_potvento: 0.9866 - val_desvpad: 0.9286 - val_wls: 0.6250
# Epoch 1958/2000
# 57/57 - 5s - loss: 768.7823 - nossa_metrica: 0.8750 - potvento: 0.9956 - desvpad: 0.9868 - wls: 0.6425 - val_loss: 7728.0888 - val_nossa_metrica: 0.7500 - val_potvento: 0.9062 - val_desvpad: 0.8527 - val_wls: 0.4911
# Epoch 1959/2000
# 57/57 - 5s - loss: 792.3714 - nossa_metrica: 0.8443 - potvento: 0.9912 - desvpad: 0.9879 - wls: 0.5537 - val_loss: 5025.8893 - val_nossa_metrica: 0.7500 - val_potvento: 0.9152 - val_desvpad: 0.8661 - val_wls: 0.4688
# Epoch 1960/2000
# 57/57 - 5s - loss: 788.9444 - nossa_metrica: 0.8322 - potvento: 0.9912 - desvpad: 0.9912 - wls: 0.5143 - val_loss: 5607.3648 - val_nossa_metrica: 0.8065 - val_potvento: 0.9866 - val_desvpad: 0.9286 - val_wls: 0.5045
# Epoch 1961/2000
# 57/57 - 5s - loss: 815.3313 - nossa_metrica: 0.9068 - potvento: 0.9912 - desvpad: 0.9868 - wls: 0.7423 - val_loss: 5608.2837 - val_nossa_metrica: 0.8720 - val_potvento: 0.9152 - val_desvpad: 0.8705 - val_wls: 0.8304
# Epoch 1962/2000
# 57/57 - 5s - loss: 805.4938 - nossa_metrica: 0.8765 - potvento: 0.9923 - desvpad: 0.9868 - wls: 0.6502 - val_loss: 5421.7517 - val_nossa_metrica: 0.7500 - val_potvento: 0.9152 - val_desvpad: 0.8661 - val_wls: 0.4688
# Epoch 1963/2000
# 57/57 - 5s - loss: 787.3711 - nossa_metrica: 0.8425 - potvento: 0.9945 - desvpad: 0.9868 - wls: 0.5461 - val_loss: 8350.7036 - val_nossa_metrica: 0.8006 - val_potvento: 0.9777 - val_desvpad: 0.9196 - val_wls: 0.5045
# Epoch 1964/2000
# 57/57 - 5s - loss: 800.2049 - nossa_metrica: 0.8344 - potvento: 0.9934 - desvpad: 0.9879 - wls: 0.5219 - val_loss: 4995.5080 - val_nossa_metrica: 0.7545 - val_potvento: 0.9152 - val_desvpad: 0.8571 - val_wls: 0.4911
# Epoch 1965/2000
# 57/57 - 5s - loss: 779.6597 - nossa_metrica: 0.9174 - potvento: 0.9956 - desvpad: 0.9912 - wls: 0.7654 - val_loss: 5573.0537 - val_nossa_metrica: 0.8229 - val_potvento: 0.9152 - val_desvpad: 0.8616 - val_wls: 0.6920
# Epoch 1966/2000
# 57/57 - 5s - loss: 781.1802 - nossa_metrica: 0.8670 - potvento: 0.9956 - desvpad: 0.9879 - wls: 0.6173 - val_loss: 7005.7426 - val_nossa_metrica: 0.8125 - val_potvento: 0.9866 - val_desvpad: 0.9241 - val_wls: 0.5268
# Epoch 1967/2000
# 57/57 - 5s - loss: 796.8305 - nossa_metrica: 0.8432 - potvento: 0.9934 - desvpad: 0.9868 - wls: 0.5493 - val_loss: 4848.7345 - val_nossa_metrica: 0.7560 - val_potvento: 0.9152 - val_desvpad: 0.8616 - val_wls: 0.4911
# Epoch 1968/2000
# 57/57 - 5s - loss: 811.1385 - nossa_metrica: 0.8425 - potvento: 0.9956 - desvpad: 0.9868 - wls: 0.5450 - val_loss: 7021.2138 - val_nossa_metrica: 0.7455 - val_potvento: 0.9107 - val_desvpad: 0.8571 - val_wls: 0.4688
# Epoch 1969/2000
# 57/57 - 5s - loss: 870.0475 - nossa_metrica: 0.9090 - potvento: 0.9956 - desvpad: 0.9803 - wls: 0.7511 - val_loss: 6042.1242 - val_nossa_metrica: 0.8065 - val_potvento: 0.9866 - val_desvpad: 0.9241 - val_wls: 0.5089
# Epoch 1970/2000
# 57/57 - 5s - loss: 881.0427 - nossa_metrica: 0.8710 - potvento: 0.9989 - desvpad: 0.9836 - wls: 0.6305 - val_loss: 6748.9260 - val_nossa_metrica: 0.7560 - val_potvento: 0.9196 - val_desvpad: 0.8571 - val_wls: 0.4911
# Epoch 1971/2000
# 57/57 - 5s - loss: 1122.6488 - nossa_metrica: 0.8366 - potvento: 1.0000 - desvpad: 0.9748 - wls: 0.5351 - val_loss: 10115.2581 - val_nossa_metrica: 0.7307 - val_potvento: 0.9196 - val_desvpad: 0.8125 - val_wls: 0.4598
# Epoch 1972/2000
# 57/57 - 5s - loss: 2646.9125 - nossa_metrica: 0.8403 - potvento: 0.9989 - desvpad: 0.9715 - wls: 0.5504 - val_loss: 7432.4719 - val_nossa_metrica: 0.8110 - val_potvento: 0.9911 - val_desvpad: 0.9375 - val_wls: 0.5045
# Epoch 1973/2000
# 57/57 - 5s - loss: 1948.0424 - nossa_metrica: 0.8984 - potvento: 0.9934 - desvpad: 0.9846 - wls: 0.7171 - val_loss: 10027.7454 - val_nossa_metrica: 0.7545 - val_potvento: 0.9018 - val_desvpad: 0.8616 - val_wls: 0.5000
# Epoch 1974/2000
# 57/57 - 5s - loss: 1063.2184 - nossa_metrica: 0.8710 - potvento: 0.9923 - desvpad: 0.9934 - wls: 0.6272 - val_loss: 6063.4618 - val_nossa_metrica: 0.7470 - val_potvento: 0.9152 - val_desvpad: 0.8571 - val_wls: 0.4688
# Epoch 1975/2000
# 57/57 - 5s - loss: 797.6949 - nossa_metrica: 0.8490 - potvento: 1.0000 - desvpad: 0.9956 - wls: 0.5515 - val_loss: 7068.6097 - val_nossa_metrica: 0.8080 - val_potvento: 0.9866 - val_desvpad: 0.9330 - val_wls: 0.5045
# Epoch 1976/2000
# 57/57 - 5s - loss: 798.3498 - nossa_metrica: 0.8388 - potvento: 0.9967 - desvpad: 0.9912 - wls: 0.5285 - val_loss: 5339.7951 - val_nossa_metrica: 0.7440 - val_potvento: 0.9196 - val_desvpad: 0.8661 - val_wls: 0.4464
# Epoch 1977/2000
# 57/57 - 5s - loss: 773.4457 - nossa_metrica: 0.9119 - potvento: 0.9956 - desvpad: 0.9912 - wls: 0.7489 - val_loss: 5278.2406 - val_nossa_metrica: 0.7515 - val_potvento: 0.9196 - val_desvpad: 0.8661 - val_wls: 0.4688
# Epoch 1978/2000
# 57/57 - 5s - loss: 737.0408 - nossa_metrica: 0.8787 - potvento: 0.9967 - desvpad: 0.9912 - wls: 0.6480 - val_loss: 7201.4649 - val_nossa_metrica: 0.8021 - val_potvento: 0.9821 - val_desvpad: 0.9196 - val_wls: 0.5045
# Epoch 1979/2000
# 57/57 - 5s - loss: 763.3775 - nossa_metrica: 0.8483 - potvento: 0.9934 - desvpad: 0.9912 - wls: 0.5603 - val_loss: 5638.8014 - val_nossa_metrica: 0.7545 - val_potvento: 0.9152 - val_desvpad: 0.8571 - val_wls: 0.4911
# Epoch 1980/2000
# 57/57 - 5s - loss: 764.9851 - nossa_metrica: 0.8450 - potvento: 0.9912 - desvpad: 0.9923 - wls: 0.5515 - val_loss: 6530.5399 - val_nossa_metrica: 0.7500 - val_potvento: 0.9152 - val_desvpad: 0.8661 - val_wls: 0.4688
# Epoch 1981/2000
# 57/57 - 5s - loss: 792.2878 - nossa_metrica: 0.9061 - potvento: 0.9912 - desvpad: 0.9868 - wls: 0.7401 - val_loss: 6051.8217 - val_nossa_metrica: 0.9286 - val_potvento: 0.9911 - val_desvpad: 0.9330 - val_wls: 0.8616
# Epoch 1982/2000
# 57/57 - 5s - loss: 779.4836 - nossa_metrica: 0.8757 - potvento: 0.9912 - desvpad: 0.9879 - wls: 0.6480 - val_loss: 5088.7634 - val_nossa_metrica: 0.7560 - val_potvento: 0.9196 - val_desvpad: 0.8571 - val_wls: 0.4911
# Epoch 1983/2000
# 57/57 - 5s - loss: 742.2515 - nossa_metrica: 0.8447 - potvento: 0.9934 - desvpad: 0.9912 - wls: 0.5493 - val_loss: 6838.6280 - val_nossa_metrica: 0.7455 - val_potvento: 0.9107 - val_desvpad: 0.8571 - val_wls: 0.4688
# Epoch 1984/2000
# 57/57 - 5s - loss: 754.3315 - nossa_metrica: 0.8359 - potvento: 0.9912 - desvpad: 0.9923 - wls: 0.5241 - val_loss: 6331.8264 - val_nossa_metrica: 0.8051 - val_potvento: 0.9866 - val_desvpad: 0.9241 - val_wls: 0.5045
# Epoch 1985/2000
# 57/57 - 5s - loss: 762.4002 - nossa_metrica: 0.9112 - potvento: 0.9912 - desvpad: 0.9912 - wls: 0.7511 - val_loss: 5911.0693 - val_nossa_metrica: 0.8140 - val_potvento: 0.9152 - val_desvpad: 0.8705 - val_wls: 0.6562
# Epoch 1986/2000
# 57/57 - 5s - loss: 778.7465 - nossa_metrica: 0.8673 - potvento: 0.9912 - desvpad: 0.9912 - wls: 0.6195 - val_loss: 5496.2691 - val_nossa_metrica: 0.7634 - val_potvento: 0.9196 - val_desvpad: 0.8705 - val_wls: 0.5000
# Epoch 1987/2000
# 57/57 - 5s - loss: 780.2546 - nossa_metrica: 0.8439 - potvento: 0.9912 - desvpad: 0.9912 - wls: 0.5493 - val_loss: 5586.8411 - val_nossa_metrica: 0.8051 - val_potvento: 0.9866 - val_desvpad: 0.9241 - val_wls: 0.5045
# Epoch 1988/2000
# 57/57 - 5s - loss: 761.6740 - nossa_metrica: 0.8472 - potvento: 0.9934 - desvpad: 0.9912 - wls: 0.5570 - val_loss: 7151.6311 - val_nossa_metrica: 0.7530 - val_potvento: 0.9107 - val_desvpad: 0.8571 - val_wls: 0.4911
# Epoch 1989/2000
# 57/57 - 5s - loss: 766.2042 - nossa_metrica: 0.9141 - potvento: 0.9912 - desvpad: 0.9901 - wls: 0.7610 - val_loss: 5888.1268 - val_nossa_metrica: 0.8095 - val_potvento: 0.9152 - val_desvpad: 0.8616 - val_wls: 0.6518
# Epoch 1990/2000
# 57/57 - 5s - loss: 764.6543 - nossa_metrica: 0.8717 - potvento: 0.9912 - desvpad: 0.9923 - wls: 0.6316 - val_loss: 6842.7632 - val_nossa_metrica: 0.8051 - val_potvento: 0.9866 - val_desvpad: 0.9241 - val_wls: 0.5045
# Epoch 1991/2000
# 57/57 - 5s - loss: 773.5688 - nossa_metrica: 0.8403 - potvento: 0.9912 - desvpad: 0.9934 - wls: 0.5362 - val_loss: 5244.6994 - val_nossa_metrica: 0.7411 - val_potvento: 0.9196 - val_desvpad: 0.8661 - val_wls: 0.4375
# Epoch 1992/2000
# 57/57 - 5s - loss: 768.1467 - nossa_metrica: 0.8359 - potvento: 0.9912 - desvpad: 0.9912 - wls: 0.5252 - val_loss: 5175.3176 - val_nossa_metrica: 0.7485 - val_potvento: 0.9152 - val_desvpad: 0.8616 - val_wls: 0.4688
# Epoch 1993/2000
# 57/57 - 5s - loss: 763.4615 - nossa_metrica: 0.8933 - potvento: 0.9934 - desvpad: 0.9912 - wls: 0.6952 - val_loss: 7647.6755 - val_nossa_metrica: 0.8065 - val_potvento: 0.9821 - val_desvpad: 0.9241 - val_wls: 0.5134
# Epoch 1994/2000
# 57/57 - 5s - loss: 768.7187 - nossa_metrica: 0.8681 - potvento: 0.9912 - desvpad: 0.9956 - wls: 0.6173 - val_loss: 5817.6795 - val_nossa_metrica: 0.7545 - val_potvento: 0.9152 - val_desvpad: 0.8571 - val_wls: 0.4911
# Epoch 1995/2000
# 57/57 - 5s - loss: 772.2443 - nossa_metrica: 0.8333 - potvento: 0.9912 - desvpad: 0.9934 - wls: 0.5154 - val_loss: 6443.6103 - val_nossa_metrica: 0.7500 - val_potvento: 0.9152 - val_desvpad: 0.8661 - val_wls: 0.4688
# Epoch 1996/2000
# 57/57 - 5s - loss: 801.2224 - nossa_metrica: 0.8553 - potvento: 0.9912 - desvpad: 0.9912 - wls: 0.5833 - val_loss: 5787.4734 - val_nossa_metrica: 0.8527 - val_potvento: 0.9911 - val_desvpad: 0.9330 - val_wls: 0.6339
# Epoch 1997/2000
# 57/57 - 5s - loss: 802.2308 - nossa_metrica: 0.9112 - potvento: 0.9912 - desvpad: 0.9923 - wls: 0.7500 - val_loss: 5105.7493 - val_nossa_metrica: 0.7545 - val_potvento: 0.9152 - val_desvpad: 0.8571 - val_wls: 0.4911
# Epoch 1998/2000
# 57/57 - 4s - loss: 754.2888 - nossa_metrica: 0.8651 - potvento: 0.9934 - desvpad: 0.9934 - wls: 0.6086 - val_loss: 7227.5853 - val_nossa_metrica: 0.7470 - val_potvento: 0.9107 - val_desvpad: 0.8616 - val_wls: 0.4688
# Epoch 1999/2000
# 57/57 - 5s - loss: 772.2094 - nossa_metrica: 0.8293 - potvento: 0.9912 - desvpad: 0.9901 - wls: 0.5066 - val_loss: 6698.3865 - val_nossa_metrica: 0.8943 - val_potvento: 0.9866 - val_desvpad: 0.9241 - val_wls: 0.7723
# Epoch 2000/2000
# 57/57 - 5s - loss: 787.8972 - nossa_metrica: 0.8589 - potvento: 0.9912 - desvpad: 0.9923 - wls: 0.5932 - val_loss: 6218.8555 - val_nossa_metrica: 0.8482 - val_potvento: 0.9152 - val_desvpad: 0.8661 - val_wls: 0.7634
# Loss de treinamento minima: 632.8036354466489
# Acuracia de treinamento maxima: 0.9780703
# Loss de valdiacao minima: 3772.486833844866
# Acuracia de validacao maxima: 0.9583333
# Time: 158.159 minutes
# Model Saved

# %%
inference_generator= power_data_generator(batch_size=1,gen_type='inference')  #Generator for getting only input data
test_input = next(inference_generator)  #Get next batch of input data from data set
print(test_input)
out = model.predict_on_batch(test_input)   #Probability predictions for giving input
print(out)
# Out:
# [[[[  3477.64]
#    [ 78900.06]]
#
#   [[  3727.94]
#    [ 75148.44]]
#
#   [[  3396.8 ]
#    [ 72802.24]]
#
#   [[  3273.75]
#    [ 71745.32]]
#
#   [[  2800.58]
#    [ 72721.22]]
#
#   [[  2346.93]
#    [ 75755.16]]
#
#   [[  2030.39]
#    [ 79904.28]]
#
#   [[  1509.42]
#    [ 84915.09]]
#
#   [[   743.17]
#    [ 89481.  ]]
#
#   [[   657.4 ]
#    [ 94311.15]]
#
#   [[   935.75]
#    [ 98981.73]]
#
#   [[  1121.12]
#    [102664.29]]
#
#   [[  1213.22]
#    [105564.29]]
#
#   [[  1431.9 ]
#    [107830.95]]
#
#   [[  1514.87]
#    [109213.87]]
#
#   [[  1719.13]
#    [109550.17]]
#
#   [[  1833.03]
#    [109127.92]]
#
#   [[  1804.25]
#    [107870.04]]
#
#   [[  1379.8 ]
#    [105518.03]]
#
#   [[  1177.16]
#    [101817.23]]
#
#   [[  1235.9 ]
#    [ 99768.25]]
#
#   [[  1482.94]
#    [ 95794.2 ]]
#
#   [[  1845.18]
#    [ 89056.8 ]]
#
#   [[  2105.73]
#    [ 82802.53]]]]
# tf.Tensor([[1.8687634e+03 8.9927954e+02 2.4579179e-02]], shape=(1, 3), dtype=float32)

# %%
# Checking accuracy for the givin input of previous code cell

soma = test_input.sum(axis=0).sum(axis=0)
media = np.mean(test_input, axis = (0,1))
desv_pad = np.std(test_input, axis = (0,1))
print("Potência gerada pelo vento = ",media[0])
print("Desvio padrado da potencia do vento = ",desv_pad[0])
wls_true = (soma[0]/24)/(soma[1]/24)
print("Wind Load Share = ", wls_true)
pot_vento_pred = out[-1][0]
desv_pad_pred = out[-1][1]
wls_pred = out[-1][2]
print("Valor predito da potencia gerada pelo vento = ", pot_vento_pred)
print("Valor predito do desvio padrao da potencia do vento = ", desv_pad_pred)
print("Valor predito do Wind Load Share = ", wls_pred)
c = 0
if (media[0] <= 4000 and pot_vento_pred <= 4000) or ((media[0] > 4000 and media[0] <= 8500) and (pot_vento_pred > 4000 and pot_vento_pred <= 8500)) or (media[0] > 8500 and pot_vento_pred > 8500):
  print("Acertou a potencia do vento!")
  c = c+1
else:
  print("Errou a potencia do vento!")
if (desv_pad[0] <= 1150 and desv_pad_pred <= 1150) or ((desv_pad[0] > 1150 and desv_pad[0] <= 2300) and (desv_pad_pred > 1150 and desv_pad_pred <= 2300)) or (desv_pad[0] > 2300 and desv_pad_pred > 2300):
  print("Acertou o desvio padrão da potencia do vento!")
  c = c+1
else:
  print("Errou o desvio padrão da potencia do vento!")
if (wls_true <= 0.075 and wls_pred <= 0.075) or (wls_true > 0.075 and wls_pred > 0.075):
  print("Acertou o Wind Load Share!")
  c = c+1
else:
  print("Errou o Wind Load Share!")
print("Percentual de acerto = ", (c/Yclasses)*100)
# Out:
# Potência gerada pelo vento =  [1865.16666667]
# Desvio padrado da potencia do vento =  [862.8141685]
# Wind Load Share =  [0.02015267]
# Valor predito da potencia gerada pelo vento =  tf.Tensor(1868.7634, shape=(), dtype=float32)
# Valor predito do desvio padrao da potencia do vento =  tf.Tensor(899.27954, shape=(), dtype=float32)
# Valor predito do Wind Load Share =  tf.Tensor(0.024579179, shape=(), dtype=float32)
# Acertou a potencia do vento!
# Acertou o desvio padrão da potencia do vento!
# Acertou o Wind Load Share!
# Percentual de acerto =  100.0

# %%
# Ploting

import matplotlib.pyplot as plt

plt.plot(history.history['nossa_metrica'])
plt.plot(history.history['val_nossa_metrica'])
plt.title('Model custom accuracy')
plt.ylabel('Custom Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='lower right')
plt.show()

plt.plot(history.history['potvento'])
plt.plot(history.history['desvpad'])
plt.plot(history.history['wls'])
plt.title('Model custom accuracy')
plt.ylabel('Custom Accuracy')
plt.xlabel('Epoch')
plt.legend(['WP Train','StDev Train','WLS Train'], loc='lower right')
plt.show()

plt.plot(history.history['val_potvento'])
plt.plot(history.history['val_desvpad'])
plt.plot(history.history['val_wls'])
plt.title('Model custom accuracy')
plt.ylabel('Custom Accuracy')
plt.xlabel('Epoch')
plt.legend(['WP Val','StDev Val','WLS Val'], loc='lower right')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
